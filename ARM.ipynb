# %% [markdown]
# <a href="https://colab.research.google.com/github/Aomaphisara/ULckdresearch2023/blob/main/ARM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##  Apriori algorithm

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# Display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', 999)
pd.options.display.float_format = "{:.3f}".format

# Apriori min support
min_support = 0.3

# Max length of apriori n-grams
max_len = 10

#frequent_items = apriori(df, use_colnames=True, min_support=min_support, max_len=max_len + 1)
#rules = association_rules(frequent_items, metric='lift', min_threshold=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## Load data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### stage 1

# %%
import pandas as pd
rules_eGFR_stage_1 = pd.read_csv('/content/drive/MyDrive/ckdresearch2023/Assign/Association rule/SMOT/egfr1_new.csv', index_col=0)
rules_eGFR_stage_1.head()
# Out:
#                          antecedents                  consequents  \
# 74        frozenset({'NATNL_Asian'})  frozenset({'eGFR_stage 1'})
# 127  frozenset({'Age_middle_adult'})  frozenset({'eGFR_stage 1'})
# 310  frozenset({'Potassium_Normal'})  frozenset({'eGFR_stage 1'})
# 385       frozenset({'Uric_Normal'})  frozenset({'eGFR_stage 1'})
# 468  frozenset({'Blood-sugar_High'})  frozenset({'eGFR_stage 1'})
#
#      antecedent support  consequent support   support  confidence      lift  \
# 74             0.996027                 0.5  0.498387    0.500375  1.000750
# 127            0.561340                 0.5  0.357979    0.637722  1.275444
# 310            0.925995                 0.5  0.465122    0.502294  1.004587
# 385            0.775606                 0.5  0.418237    0.539239  1.078478
# 468            0.644067                 0.5  0.363977    0.565123  1.130246
#
#      leverage  conviction  zhangs_metric
# 74   0.000374    1.000751       0.188728
# ...

# %%
rules_eGFR_stage_1.shape
# Out:
# (116, 10)

# %%
# ใช้ query เพื่อเลือกรายการที่มี support ที่เริ่มต้นที่ 0.5 แต่น้อยกว่า 0.6
stage_1 = rules_eGFR_stage_1.query('support >= 0.3 and confidence >= 0.5 ').sort_values(by='confidence', ascending=False)

# แสดงผลลัพธ์
stage_1.shape
# Out:
# (116, 10)

# %%
# ใช้ query เพื่อเลือกรายการที่มี support ที่เริ่มต้นที่ 0.5 แต่น้อยกว่า 0.6
stage_1 = rules_eGFR_stage_1.query('support >= 0.3 and confidence >= 0.6 ').sort_values(by='confidence', ascending=False)

# แสดงผลลัพธ์
stage_1.shape
# Out:
# (17, 10)

# %%
stage_1.head()
# Out:
#                                              antecedents  \
# 3850      frozenset({'Uric_Normal', 'Age_middle_adult'})
# 26028  frozenset({'NATNL_Asian', 'Uric_Normal', 'Age_...
# 3905      frozenset({'UPCR_Normal', 'Age_middle_adult'})
# 3745   frozenset({'Potassium_Normal', 'Age_middle_adu...
# 25755  frozenset({'NATNL_Asian', 'Age_middle_adult', ...
#
#                        consequents  antecedent support  consequent support  \
# 3850   frozenset({'eGFR_stage 1'})            0.444885                 0.5
# 26028  frozenset({'eGFR_stage 1'})            0.443302                 0.5
# 3905   frozenset({'eGFR_stage 1'})            0.465800                 0.5
# 3745   frozenset({'eGFR_stage 1'})            0.521967                 0.5
# 25755  frozenset({'eGFR_stage 1'})            0.520296                 0.5
#
#         support  confidence      lift  leverage  conviction  zhangs_metric
# 3850   0.302991    0.681056  1.362111  0.080549    1.567672       0.478902
# ...

# %% [markdown]
# #### stage 2

# %%
import pandas as pd
rules_eGFR_stage_2 = pd.read_csv('/content/drive/MyDrive/ckdresearch2023/Assign/Association rule/SMOT/egfr2_new.csv', index_col=0)
rules_eGFR_stage_2.head()
# Out:
#                          antecedents                  consequents  \
# 75        frozenset({'NATNL_Asian'})  frozenset({'eGFR_stage 2'})
# 304        frozenset({'BUN_Normal'})  frozenset({'eGFR_stage 2'})
# 306     frozenset({'Sodium_Normal'})  frozenset({'eGFR_stage 2'})
# 308  frozenset({'Potassium_Normal'})  frozenset({'eGFR_stage 2'})
# 311   frozenset({'Chloride_Normal'})  frozenset({'eGFR_stage 2'})
#
#      antecedent support  consequent support   support  confidence      lift  \
# 75             0.995344            0.380008  0.378563    0.380334  1.000859
# 304            0.702851            0.380008  0.322596    0.458982  1.207824
# 306            0.933276            0.380008  0.359141    0.384817  1.012657
# 308            0.922368            0.380008  0.360471    0.390811  1.028429
# 311            0.917788            0.380008  0.355872    0.387750  1.020374
#
#      leverage  conviction  zhangs_metric
# 75   0.000325    1.000527       0.184391
# ...

# %%
rules_eGFR_stage_2.shape
# Out:
# (334, 10)

# %%
# ใช้ query เพื่อเลือกรายการที่มี support ที่เริ่มต้นที่ 0.5 แต่น้อยกว่า 0.6
stage_2 = rules_eGFR_stage_2.query('support >= 0.3 and confidence >= 0.3').sort_values(by='confidence', ascending=False)

# แสดงผลลัพธ์
stage_2.shape
# Out:
# (334, 10)

# %% [markdown]
# #### stage 3

# %%
import pandas as pd
rules_eGFR_stage_3 = pd.read_csv('/content/drive/MyDrive/ckdresearch2023/Assign/Association rule/SMOT/egfr3_new.csv', index_col=0)
rules_eGFR_stage_3.head()
# Out:
#                       antecedents                  consequents  \
# 14      frozenset({'OutPatient'})  frozenset({'eGFR_stage 3'})
# 161      frozenset({'Age_Older'})  frozenset({'eGFR_stage 3'})
# 224        frozenset({'BSA_Low'})  frozenset({'eGFR_stage 3'})
# 247     frozenset({'DBP_Normal'})  frozenset({'eGFR_stage 3'})
# 311  frozenset({'Sodium_Normal'})  frozenset({'eGFR_stage 3'})
#
#      antecedent support  consequent support   support  confidence      lift  \
# 14             0.868890            0.520429  0.461345    0.530960  1.020233
# 161            0.566268            0.520429  0.333124    0.588281  1.130375
# 224            0.771551            0.520429  0.404979    0.524890  1.008570
# 247            0.722254            0.520429  0.388217    0.537508  1.032817
# 311            0.933276            0.520429  0.487647    0.522511  1.004000
#
#      leverage  conviction  zhangs_metric
# 14   0.009149    1.022450       0.151263
# 161  0.038422    1.164800       0.265920
# ...

# %%
rules_eGFR_stage_3.shape
# Out:
# (4918, 10)

# %%
# ใช้ query เพื่อเลือกรายการที่มี support ที่เริ่มต้นที่ 0.5 แต่น้อยกว่า 0.6
stage3 = rules_eGFR_stage_3.query('support >= 0.3 and confidence >= 0.5').sort_values(by='confidence', ascending=False)

# แสดงผลลัพธ์
stage3.shape
# Out:
# (4918, 10)

# %%
# ใช้ query เพื่อเลือกรายการที่มี support ที่เริ่มต้นที่ 0.5 แต่น้อยกว่า 0.6
stage3 = rules_eGFR_stage_3.query('support >= 0.3 and confidence >= 0.6').sort_values(by='confidence', ascending=False)

# แสดงผลลัพธ์
stage3.shape
# Out:
# (0, 10)

# %%
# ใช้ query เพื่อเลือกรายการที่มี support ที่เริ่มต้นที่ 0.5 แต่น้อยกว่า 0.6
stage3 = rules_eGFR_stage_3.query('support >= 0.4 and confidence >= 0.5').sort_values(by='confidence', ascending=False)

# แสดงผลลัพธ์
stage3.shape
# Out:
# (413, 10)

# %%
#stage3.to_csv('/content/drive/MyDrive/ckdresearch2023/Assign/Association rule/SMOT/rule_stage3_neww.csv')

# %% [markdown]
# ### stage 4

# %%
import pandas as pd
rule_egfr_4 = pd.read_csv('/content/drive/MyDrive/ckdresearch2023/Assign/Association rule/SMOT/egfr4_new.csv', index_col=0)
rule_egfr_4.head()
# Out:
#                    antecedents                  consequents  \
# 152   frozenset({'Age_Older'})  frozenset({'eGFR_stage 4'})
# 195     frozenset({'BSA_Low'})  frozenset({'eGFR_stage 4'})
# 228  frozenset({'DBP_Normal'})  frozenset({'eGFR_stage 4'})
# 274    frozenset({'BUN_High'})  frozenset({'eGFR_stage 4'})
# 392   frozenset({'Uric_High'})  frozenset({'eGFR_stage 4'})
#
#      antecedent support  consequent support   support  confidence      lift  \
# 152            0.604914                 0.5  0.324876    0.537061  1.074122
# 195            0.786026                 0.5  0.401614    0.510942  1.021885
# 228            0.734430                 0.5  0.374780    0.510300  1.020600
# 274            0.548923                 0.5  0.446451    0.813323  1.626646
# 392            0.435257                 0.5  0.309807    0.711778  1.423556
#
#      leverage  conviction  zhangs_metric
# 152  0.022419    1.080056       0.174663
# 195  0.008601    1.022374       0.100087
# ...

# %%
rule_egfr_4.shape
# Out:
# (1366, 10)

# %%
# ใช้ query เพื่อเลือกรายการที่มี support ที่เริ่มต้นที่ 0.5 แต่น้อยกว่า 0.6
stage_4 = rule_egfr_4.query('support >= 0.3 and confidence >= 0.6').sort_values(by='confidence', ascending=False)

# แสดงผลลัพธ์
stage_4.shape
# Out:
# (1135, 10)

# %%
#stage_4.to_csv('/content/drive/MyDrive/ckdresearch2023/Assign/Association rule/SMOT/rule_stage4_neww.csv')

# %%
# ใช้ query เพื่อเลือกรายการที่มี support ที่เริ่มต้นที่ 0.5 แต่น้อยกว่า 0.6
stage_4 = rule_egfr_4.query('support >= 0.4 and confidence >= 0.6').sort_values(by='confidence', ascending=False)

# แสดงผลลัพธ์
stage_4.shape
# Out:
# (17, 10)

# %%
stage_4.head()
# Out:
#                                              antecedents  \
# 6981        frozenset({'BUN_High', 'Phosphorus_Normal'})
# 35749  frozenset({'NATNL_Asian', 'BUN_High', 'Phospho...
# 274                              frozenset({'BUN_High'})
# 2504              frozenset({'NATNL_Asian', 'BUN_High'})
# 6936           frozenset({'BUN_High', 'Calcium_Normal'})
#
#                        consequents  antecedent support  consequent support  \
# 6981   frozenset({'eGFR_stage 4'})            0.503815                 0.5
# 35749  frozenset({'eGFR_stage 4'})            0.500210                 0.5
# 274    frozenset({'eGFR_stage 4'})            0.548923                 0.5
# 2504   frozenset({'eGFR_stage 4'})            0.544807                 0.5
# 6936   frozenset({'eGFR_stage 4'})            0.500771                 0.5
#
#         support  confidence      lift  leverage  conviction  zhangs_metric
# 6981   0.411226    0.816225  1.632450  0.159319    2.720720       0.780805
# ...

# %% [markdown]
# ### stage 5

# %%
import pandas as pd
rule_egfr_5 = pd.read_csv('/content/drive/MyDrive/ckdresearch2023/Assign/Association rule/SMOT/egfr5_new.csv', index_col=0)
rule_egfr_5.head()
# Out:
#                        antecedents                  consequents  \
# 65      frozenset({'NATNL_Asian'})  frozenset({'eGFR_stage 5'})
# 195         frozenset({'BSA_Low'})  frozenset({'eGFR_stage 5'})
# 247        frozenset({'BUN_High'})  frozenset({'eGFR_stage 5'})
# 425  frozenset({'Hemoglobin_Low'})  frozenset({'eGFR_stage 5'})
# 437  frozenset({'Hematocrit_Low'})  frozenset({'eGFR_stage 5'})
#
#      antecedent support  consequent support   support  confidence      lift  \
# 65             0.996798                 0.5  0.499151    0.500755  1.001510
# 195            0.798127                 0.5  0.412881    0.517312  1.034624
# 247            0.599986                 0.5  0.485136    0.808578  1.617157
# 425            0.753612                 0.5  0.472963    0.627595  1.255190
# 437            0.681511                 0.5  0.455775    0.668771  1.337542
#
#      leverage  conviction  zhangs_metric
# 65   0.000752    1.001512       0.470679
# ...

# %%
rule_egfr_5.shape
# Out:
# (502, 10)

# %%
# ใช้ query เพื่อเลือกรายการที่มี support ที่เริ่มต้นที่ 0.5 แต่น้อยกว่า 0.6
stage_5 = rule_egfr_5.query('support >= 0.3 and confidence >= 0.6').sort_values(by='confidence', ascending=False)

# แสดงผลลัพธ์
stage_5.shape
# Out:
# (439, 10)

# %%
#stage_5.to_csv('/content/drive/MyDrive/ckdresearch2023/Assign/Association rule/SMOT/rule_stage5_neww.csv')

# %%
# ใช้ query เพื่อเลือกรายการที่มี support ที่เริ่มต้นที่ 0.5 แต่น้อยกว่า 0.6
stage5_1 = rule_egfr_5.query('support >= 0.4  and confidence >= 0.6').sort_values(by='confidence', ascending=False)

# แสดงผลลัพธ์
stage5_1.shape
# Out:
# (36, 10)

# %%
stage5_1.head()
# Out:
#                                               antecedents  \
# 261947  frozenset({'Hematocrit_Low', 'BUN_High', 'Hemo...
# 172768  frozenset({'Hematocrit_Low', 'BUN_High', 'Chol...
# 53621   frozenset({'Cholesterol_Desirable', 'BUN_High'...
# 172022  frozenset({'Hematocrit_Low', 'BUN_High', 'Hemo...
# 53269   frozenset({'Hematocrit_Low', 'BUN_High', 'Hemo...
#
#                         consequents  antecedent support  consequent support  \
# 261947  frozenset({'eGFR_stage 5'})            0.466761                 0.5
# 172768  frozenset({'eGFR_stage 5'})            0.466597                 0.5
# 53621   frozenset({'eGFR_stage 5'})            0.467842                 0.5
# 172022  frozenset({'eGFR_stage 5'})            0.522243                 0.5
# 53269   frozenset({'eGFR_stage 5'})            0.523545                 0.5
#
#          support  confidence      lift  leverage  conviction  zhangs_metric
# 261947  0.400206    0.857412  1.714823  0.166826    3.506594       0.781731
# ...
