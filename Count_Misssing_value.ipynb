# %% [markdown]
# <a href="https://colab.research.google.com/github/Aomaphisara/ULckdresearch2023/blob/main/Count_Misssing_value.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_excel('/content/drive/MyDrive/ckdresearch2023/Assign/SummaryFile/WideTable/WideTable(ยังไม่ตัด).xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0  PatientUID  Recent_Creatinine  Recent_eGFR  \
# 0           0      924852               2.63         15.8
# 1           1      989278               2.03         32.3
# 2           2     2103792               1.05         55.9
# 3           3      953611               1.03         51.1
# 4           4      488150               1.94         32.6
#
#                Recent_Date  PatientVisitUID     Slopes  G1M2:ARB  G3M1:Statin  \
# 0  2560-08-07 12:32:50.527          3349148   2.754717         0           30
# 1  2560-08-11 08:22:48.737          3348711 -46.720000         0            0
# 2  2560-08-14 14:38:44.150          3369057  11.018868         0            0
# 3  2560-08-15 02:05:01.323          3366405  17.222520         0            0
# 4  2560-08-15 09:18:43.240          3356167 -79.002653         0            0
#
#    G5M2:NSAIDs  ...  L25:Parathyroid hormone  L26:Vitamin D  \
# 0            0  ...                      NaN            NaN
# 1            0  ...                      NaN            NaN
# 2            0  ...                      NaN            NaN
# 3            0  ...                      NaN            NaN
# 4            0  ...                      NaN            NaN
#
#    L27:UrineAlbumin/Cr ratio  L28:UrineProtein/Cr ratio  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                       17.0
#
#    L29:UrineVolume (24hrs)  L30:UrineUrea (24hrs)  L31:UrineSodium (24hrs)  \
# 0                      NaN                    NaN                      NaN
# 1                      NaN                    NaN                      NaN
# 2                      NaN                    NaN                      NaN
# 3                      NaN                    NaN                      NaN
# 4                      NaN                    NaN                      NaN
#
#    L32:UrineProtein (24hrs)                                LabLocation  \
# 0                       NaN  ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
# 1                       NaN            ห้องปฏิบัติการจุลทรรศน์วินิจฉัย
# 2                       NaN  ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
# 3                       NaN            ห้องปฏิบัติการจุลทรรศน์วินิจฉัย
# 4                       NaN  ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
#
#                   LabCwhen
# 0  2559-08-01 08:15:57.943
# 1  2559-08-01 09:14:12.527
# 2  2559-08-08 09:42:53.923
# 3  2559-08-06 10:35:19.840
# 4  2559-08-03 08:44:33.377
#
# [5 rows x 94 columns]

# %%
null_df = df.isnull()
null_count = null_df.sum()
null_count_sorted = null_count.sort_values()

total_records = len(df)
null_percentage = (null_count_sorted / total_records) * 100

import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 15))  # Adjust the figsize to control the plot size
ax = null_count_sorted.plot(kind='barh', color='skyblue', edgecolor='none')  # Use 'barh' for horizontal bars
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

plt.title('Columns with Null Values and Their Counts')
plt.xlabel('Number of Null Values')
plt.ylabel('Columns')
plt.tight_layout()
label_distance = 10
for i, v in enumerate(null_count_sorted):
    ax.text(v + label_distance, i, f"{v} ({null_percentage.iloc[i]:.2f}%)", color='black', va='center')

plt.show()

# %%
df.shape
# Out:
# (52620, 94)

# %%
# สร้างตัวแปรมาเก็บค่า Missing โดยรวม "PatientUID", "Slopes", "Recent_eGFR" เป็นคอลัมน์ที่ไม่มี Missing
missing_columns = df.columns[(df.isnull().any()) | (df.columns.isin([ "PatientUID", "Slopes", "Recent_eGFR"]))].tolist()
# สร้าง DataFrame ที่มีเฉพาะคอลัมน์ที่มีค่าที่หายไป
stage = df[missing_columns]
stage.head() #36 คอลัมน์ที่มีค่าว่าง
# Out:
#    PatientUID  Recent_eGFR     Slopes    BMI   BSA  Diastolic BP  Systolic BP  \
# 0      924852         15.8   2.754717    NaN   NaN          53.0        131.0
# 1      989278         32.3 -46.720000  18.71  1.70          71.0        121.0
# 2     2103792         55.9  11.018868  23.56  1.47          93.0        143.0
# 3      953611         51.1  17.222520  27.50  1.41          60.0        120.0
# 4      488150         32.6 -79.002653    NaN   NaN           NaN          NaN
#
#    L1:eGFR  L2:BUN  L3:Creatinine  ...  L23:LDL Cholesterol  \
# 0     13.0     NaN            3.1  ...                  NaN
# 1     80.3     5.2            1.0  ...                  NaN
# 2     44.7    22.6            1.3  ...                  NaN
# 3     33.5    28.9            1.5  ...                147.0
# 4    114.2     NaN            0.7  ...                  NaN
#
#    L24:HDL Cholesterol  L25:Parathyroid hormone  L26:Vitamin D  \
# 0                  NaN                      NaN            NaN
# 1                  NaN                      NaN            NaN
# 2                  NaN                      NaN            NaN
# 3                 30.0                      NaN            NaN
# 4                  NaN                      NaN            NaN
#
#    L27:UrineAlbumin/Cr ratio  L28:UrineProtein/Cr ratio  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                       17.0
#
#    L29:UrineVolume (24hrs)  L30:UrineUrea (24hrs)  L31:UrineSodium (24hrs)  \
# 0                      NaN                    NaN                      NaN
# 1                      NaN                    NaN                      NaN
# 2                      NaN                    NaN                      NaN
# 3                      NaN                    NaN                      NaN
# 4                      NaN                    NaN                      NaN
#
#    L32:UrineProtein (24hrs)
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 39 columns]

# %% [markdown]
# ##แบ่งระยะโรคไตตามค่า eGFR 5 ระยะ
# * ระยะที่ 1 มีค่า > 90 ขึ้นไป
# * ระยะที่ 2  มีค่าอยู่ระหว่าง 89-60
# * ระยะที่ 3  มีค่าอยุ๋ระหว่าง 59-30
# * ระยะที่ 4 มีค่าอยู่ระหว่าง 29-15
# * ระยะที่ 5 มีค่า <15

# %%
# สร้างฟังก์ชันสำหรับแบ่งข้อมูลตามระดับ 'Recent_eGFR'
def categorize_eGFR(eGFR_value):
    if eGFR_value >= 90:
        return 'Stage 1'
    elif 89.99 >= eGFR_value >= 60:
        return 'Stage 2'
    elif 59.99 >= eGFR_value >= 45:
        return 'Stage 3a'
    elif 44.99 >= eGFR_value >= 30:
        return 'Stage 3b'
    elif 29.99 >= eGFR_value >= 15:
        return 'Stage 4'
    else:
        return 'Stage 5'

# เพิ่มคอลัมน์ 'eGFR_Category' ที่บอกระดับของ 'Recent_eGFR'
stage['eGFR_Category'] = stage['Recent_eGFR'].apply(categorize_eGFR)
stage.head()
# Out:
# <ipython-input-9-d27e3363694d>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stage['eGFR_Category'] = stage['Recent_eGFR'].apply(categorize_eGFR)
#    PatientUID  Recent_eGFR     Slopes    BMI   BSA  Diastolic BP  Systolic BP  \
# 0      924852         15.8   2.754717    NaN   NaN          53.0        131.0
# 1      989278         32.3 -46.720000  18.71  1.70          71.0        121.0
# 2     2103792         55.9  11.018868  23.56  1.47          93.0        143.0
# 3      953611         51.1  17.222520  27.50  1.41          60.0        120.0
# 4      488150         32.6 -79.002653    NaN   NaN           NaN          NaN
#
#    L1:eGFR  L2:BUN  L3:Creatinine  ...  L24:HDL Cholesterol  \
# 0     13.0     NaN            3.1  ...                  NaN
# 1     80.3     5.2            1.0  ...                  NaN
# 2     44.7    22.6            1.3  ...                  NaN
# 3     33.5    28.9            1.5  ...                 30.0
# 4    114.2     NaN            0.7  ...                  NaN
#
#    L25:Parathyroid hormone  L26:Vitamin D  L27:UrineAlbumin/Cr ratio  \
# 0                      NaN            NaN                        NaN
# 1                      NaN            NaN                        NaN
# 2                      NaN            NaN                        NaN
# 3                      NaN            NaN                        NaN
# 4                      NaN            NaN                        NaN
#
#    L28:UrineProtein/Cr ratio  L29:UrineVolume (24hrs)  L30:UrineUrea (24hrs)  \
# 0                        NaN                      NaN                    NaN
# 1                        NaN                      NaN                    NaN
# 2                        NaN                      NaN                    NaN
# 3                        NaN                      NaN                    NaN
# 4                       17.0                      NaN                    NaN
#
#    L31:UrineSodium (24hrs)  L32:UrineProtein (24hrs)  eGFR_Category
# 0                      NaN                       NaN        Stage 4
# 1                      NaN                       NaN       Stage 3b
# 2                      NaN                       NaN       Stage 3a
# 3                      NaN                       NaN       Stage 3a
# 4                      NaN                       NaN       Stage 3b
#
# [5 rows x 40 columns]

# %%
stage.columns
# Out:
# Index(['PatientUID', 'Recent_eGFR', 'Slopes', 'BMI', 'BSA', 'Diastolic BP',
#        'Systolic BP', 'L1:eGFR', 'L2:BUN', 'L3:Creatinine', 'L4:Sodium',
#        'L5:Potassium', 'L6:Chloride', 'L7:Bicarbonate', 'L8:Uric',
#        'L9:Calcium', 'L10:Phosphorus', 'L11:Albumin', 'L12:Hemoglobin',
#        'L13:Hematocrit', 'L14:WBC', 'L15:Platelet', 'L16:TIBC',
#        'L17:Tranferin SAT', 'L18:Ferritin', 'L19:Blood sugar', 'L20:HbA1c',
#        'L21:Cholesterol', 'L22:Triglyceride', 'L23:LDL Cholesterol',
#        'L24:HDL Cholesterol', 'L25:Parathyroid hormone', 'L26:Vitamin D',
#        'L27:UrineAlbumin/Cr ratio', 'L28:UrineProtein/Cr ratio',
#        'L29:UrineVolume (24hrs)', 'L30:UrineUrea (24hrs)',
#        'L31:UrineSodium (24hrs)', 'L32:UrineProtein (24hrs)', 'eGFR_Category'],
#       dtype='object')

# %%
#เรียงให้คอลัมน์  'PatientUID', 'Slopes','Recent_eGFR','eGFR_Category' มาอยู่ด้านหน้า
column_order = ['PatientUID', 'Slopes', 'Recent_eGFR', 'eGFR_Category'] + [col for col in stage.columns if col not in ['PatientUID', 'Slopes', 'Recent_eGFR', 'eGFR_Category']]
data1 = stage[column_order]
data1
# Out:
#        PatientUID     Slopes  Recent_eGFR eGFR_Category    BMI   BSA  \
# 0          924852   2.754717        15.80       Stage 4    NaN   NaN
# 1          989278 -46.720000        32.30      Stage 3b  18.71  1.70
# 2         2103792  11.018868        55.90      Stage 3a  23.56  1.47
# 3          953611  17.222520        51.10      Stage 3a  27.50  1.41
# 4          488150 -79.002653        32.60      Stage 3b    NaN   NaN
# ...           ...        ...          ...           ...    ...   ...
# 52615       43763  -4.929870        55.28      Stage 3a    NaN   NaN
# 52616       43763  16.017287        55.28      Stage 3a  35.26  2.03
# 52617       43763 -24.861814        55.28      Stage 3a    NaN   NaN
# 52618       43763   4.558175        55.28      Stage 3a    NaN   NaN
# 52619       43763   2.708378        55.28      Stage 3a  32.77  2.02
#
#        Diastolic BP  Systolic BP  L1:eGFR  L2:BUN  ...  L23:LDL Cholesterol  \
# 0              53.0        131.0    13.00     NaN  ...                  NaN
# 1              71.0        121.0    80.30     5.2  ...                  NaN
# 2              93.0        143.0    44.70    22.6  ...                  NaN
# 3              60.0        120.0    33.50    28.9  ...                147.0
# 4               NaN          NaN   114.20     NaN  ...                  NaN
# ...             ...          ...      ...     ...  ...                  ...
# 52615           NaN          NaN    73.30    25.0  ...                122.0
# 52616          66.0        147.0    68.10    24.8  ...                101.0
# 52617           NaN          NaN    84.60    17.8  ...                113.0
# 52618           NaN          NaN    56.06    23.8  ...                112.0
# 52619          80.0        124.0    61.33     NaN  ...                 92.0
#
#        L24:HDL Cholesterol  L25:Parathyroid hormone  L26:Vitamin D  \
# 0                      NaN                      NaN            NaN
# 1                      NaN                      NaN            NaN
# 2                      NaN                      NaN            NaN
# 3                     30.0                      NaN            NaN
# 4                      NaN                      NaN            NaN
# ...                    ...                      ...            ...
# 52615                 37.0                      NaN            NaN
# 52616                 41.0                      NaN            NaN
# 52617                 40.0                      NaN            NaN
# 52618                 39.0                      NaN            NaN
# 52619                 41.0                      NaN            NaN
#
#        L27:UrineAlbumin/Cr ratio  L28:UrineProtein/Cr ratio  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                       17.0
# ...                          ...                        ...
# 52615                        NaN                        NaN
# 52616                        NaN                        NaN
# 52617                        NaN                        NaN
# 52618                        NaN                        NaN
# 52619                        NaN                        NaN
#
#        L29:UrineVolume (24hrs)  L30:UrineUrea (24hrs)  \
# 0                          NaN                    NaN
# 1                          NaN                    NaN
# 2                          NaN                    NaN
# 3                          NaN                    NaN
# 4                          NaN                    NaN
# ...                        ...                    ...
# 52615                      NaN                    NaN
# 52616                      NaN                    NaN
# 52617                      NaN                    NaN
# 52618                      NaN                    NaN
# 52619                      NaN                    NaN
#
#        L31:UrineSodium (24hrs)  L32:UrineProtein (24hrs)
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ...                        ...                       ...
# 52615                      NaN                       NaN
# 52616                      NaN                       NaN
# 52617                      NaN                       NaN
# 52618                      NaN                       NaN
# 52619                      NaN                       NaN
#
# [52620 rows x 40 columns]

# %%
import pandas as pd

# นับจำนวนข้อมูลแต่ละระดับของ 'eGFR_Category'
eGFR_count = stage['eGFR_Category'].value_counts()

# สร้าง DataFrame จาก Series ของ eGFR_count
df_eGFR_count = pd.DataFrame({'Count': eGFR_count})

# เพิ่มคอลัมน์ 'eGFR_Category' จาก index
df_eGFR_count['eGFR_Category'] = df_eGFR_count.index

# สลับตำแหน่งคอลัมน์ 'eGFR_Category' ขึ้นไปอยู่ที่ตำแหน่งแรกของ DataFrame
df_eGFR_count = df_eGFR_count[['eGFR_Category', 'Count']]

# จัดลำดับ DataFrame ตาม 'eGFR_Category'
df_eGFR_count_sorted = df_eGFR_count.sort_values(by='eGFR_Category').reset_index(drop=True)

# แสดง DataFrame ที่เรียงลำดับตาม 'eGFR_Category' และมี 'eGFR_Category' ขึ้นก่อน
df_eGFR_count_sorted
# Out:
#   eGFR_Category  Count
# 0       Stage 1    625
# 1       Stage 2  13889
# 2      Stage 3a  21227
# 3      Stage 3b  10088
# 4       Stage 4   4239
# 5       Stage 5   2552

# %% [markdown]
# ##ระยะที่ 1

# %%
# ใช้ตัวกรองเพื่อเลือกข้อมูลที่มี 'eGFR_Category' เป็น 'ระยะที่ 1'
stage1 = data1[data1['eGFR_Category'] == 'Stage 1']
stage1 # 1759 rows
# Out:
#        PatientUID     Slopes  Recent_eGFR eGFR_Category    BMI   BSA  \
# 93        1407655 -11.244949       100.30       Stage 1    NaN   NaN
# 107       2304528  72.432222       109.50       Stage 1    NaN   NaN
# 133       1946107 -59.475059       100.50       Stage 1    NaN   NaN
# 200       1138015 -14.531616        95.50       Stage 1   0.22  7.25
# 211       1486805   2.085714        95.90       Stage 1  24.56  1.57
# ...           ...        ...          ...           ...    ...   ...
# 52124      218497 -20.531250        97.68       Stage 1    NaN   NaN
# 52125      218497   9.258910        97.68       Stage 1    NaN   NaN
# 52126      218497  -3.510562        97.68       Stage 1    NaN   NaN
# 52127      218497  13.338929        97.68       Stage 1    NaN   NaN
# 52243     3314119  10.568365       122.30       Stage 1    NaN   NaN
#
#        Diastolic BP  Systolic BP  L1:eGFR  L2:BUN  ...  L23:LDL Cholesterol  \
# 93             71.0         94.0   126.90     7.6  ...                  NaN
# 107            99.0        145.0    20.20    39.5  ...                  NaN
# 133             NaN          NaN    97.20     NaN  ...                138.0
# 200            76.0        115.0    79.80     3.2  ...                  NaN
# 211            71.0        124.0    55.50    12.8  ...                  NaN
# ...             ...          ...      ...     ...  ...                  ...
# 52124          68.0        147.0    83.10     9.8  ...                  NaN
# 52125           NaN          NaN    62.40     NaN  ...                  NaN
# 52126          67.0        161.0    74.50    15.7  ...                 91.0
# 52127          67.0        146.0    70.22    12.1  ...                  NaN
# 52243         106.0        144.0    27.69    15.5  ...                  NaN
#
#        L24:HDL Cholesterol  L25:Parathyroid hormone  L26:Vitamin D  \
# 93                     NaN                      NaN            NaN
# 107                    NaN                      NaN            NaN
# 133                   46.0                      NaN            NaN
# 200                    NaN                      NaN            NaN
# 211                    NaN                      NaN            NaN
# ...                    ...                      ...            ...
# 52124                  NaN                      NaN            NaN
# 52125                  NaN                      NaN            NaN
# 52126                 47.0                      NaN            NaN
# 52127                  NaN                      NaN            NaN
# 52243                  NaN                      NaN            NaN
#
#        L27:UrineAlbumin/Cr ratio  L28:UrineProtein/Cr ratio  \
# 93                           NaN                        NaN
# 107                          NaN                        NaN
# 133                          NaN                        NaN
# 200                          NaN                        NaN
# 211                          NaN                        NaN
# ...                          ...                        ...
# 52124                        NaN                        NaN
# 52125                        NaN                        NaN
# 52126                        NaN                        NaN
# 52127                        NaN                        NaN
# 52243                        NaN                        NaN
#
#        L29:UrineVolume (24hrs)  L30:UrineUrea (24hrs)  \
# 93                         NaN                    NaN
# 107                        NaN                    NaN
# 133                        NaN                    NaN
# 200                        NaN                    NaN
# 211                        NaN                    NaN
# ...                        ...                    ...
# 52124                      NaN                    NaN
# 52125                      NaN                    NaN
# 52126                      NaN                    NaN
# 52127                      NaN                    NaN
# 52243                      NaN                    NaN
#
#        L31:UrineSodium (24hrs)  L32:UrineProtein (24hrs)
# 93                         NaN                       NaN
# 107                        NaN                       NaN
# 133                        NaN                       NaN
# 200                        NaN                       NaN
# 211                        NaN                       NaN
# ...                        ...                       ...
# 52124                      NaN                       NaN
# 52125                      NaN                       NaN
# 52126                      NaN                       NaN
# 52127                      NaN                       NaN
# 52243                      NaN                       NaN
#
# [625 rows x 40 columns]

# %%
# คำนวณจำนวนค่าที่ขาดหายไปในแต่ละคอลัมน์
stage1_missing = stage1.isnull().sum()

# คำนวณเปอร์เซ็นต์ของค่าที่ขาดหายไปในแต่ละคอลัมน์
missing_percent = 100 * stage1_missing / len(stage1)

# สร้าง DataFrame ที่ประกอบด้วยจำนวนค่าที่ขาดหายไปและเปอร์เซ็นต์ของค่าที่ขาดหายไป
missing1 = pd.DataFrame({
    'Stage1_Missing Values': stage1_missing,
    'Stage1_Missing Values (%)': missing_percent.round(2)  # ปัดทศนิยมในคอลัมน์ 'Missing Values (%)' เป็น 2 ตำแหน่ง
})

# แสดงผลลัพธ์ DataFrame ที่ถูกเรียงลำดับ
missing1
# Out:
#                            Stage1_Missing Values  Stage1_Missing Values (%)
# PatientUID                                     0                       0.00
# Slopes                                         0                       0.00
# Recent_eGFR                                    0                       0.00
# eGFR_Category                                  0                       0.00
# BMI                                          223                      35.68
# BSA                                          224                      35.84
# Diastolic BP                                  79                      12.64
# Systolic BP                                   79                      12.64
# L1:eGFR                                        0                       0.00
# L2:BUN                                       135                      21.60
# L3:Creatinine                                  0                       0.00
# L4:Sodium                                    220                      35.20
# L5:Potassium                                 205                      32.80
# L6:Chloride                                  220                      35.20
# L7:Bicarbonate                               219                      35.04
# L8:Uric                                      531                      84.96
# L9:Calcium                                   428                      68.48
# L10:Phosphorus                               434                      69.44
# L11:Albumin                                  242                      38.72
# L12:Hemoglobin                               150                      24.00
# L13:Hematocrit                               139                      22.24
# L14:WBC                                      139                      22.24
# L15:Platelet                                 139                      22.24
# L16:TIBC                                     613                      98.08
# L17:Tranferin SAT                            614                      98.24
# L18:Ferritin                                 614                      98.24
# L19:Blood sugar                              387                      61.92
# L20:HbA1c                                    446                      71.36
# L21:Cholesterol                              225                      36.00
# L22:Triglyceride                             431                      68.96
# L23:LDL Cholesterol                          416                      66.56
# L24:HDL Cholesterol                          440                      70.40
# L25:Parathyroid hormone                      610                      97.60
# L26:Vitamin D                                602                      96.32
# L27:UrineAlbumin/Cr ratio                    622                      99.52
# L28:UrineProtein/Cr ratio                    558                      89.28
# L29:UrineVolume (24hrs)                      621                      99.36
# L30:UrineUrea (24hrs)                        621                      99.36
# L31:UrineSodium (24hrs)                      623                      99.68
# L32:UrineProtein (24hrs)                     620                      99.20

# %%
# สร้างตัวแปรเพื่อเก็บเฉพาะค่าว่าง
stage1_missing_values_only = missing1[missing1['Stage1_Missing Values'] > 0]

# แสดงผลลัพธ์ DataFrame ที่เก็บเฉพาะค่าว่าง
stage1_missing_values_only
# Out:
#                            Stage1_Missing Values  Stage1_Missing Values (%)
# BMI                                          223                      35.68
# BSA                                          224                      35.84
# Diastolic BP                                  79                      12.64
# Systolic BP                                   79                      12.64
# L2:BUN                                       135                      21.60
# L4:Sodium                                    220                      35.20
# L5:Potassium                                 205                      32.80
# L6:Chloride                                  220                      35.20
# L7:Bicarbonate                               219                      35.04
# L8:Uric                                      531                      84.96
# L9:Calcium                                   428                      68.48
# L10:Phosphorus                               434                      69.44
# L11:Albumin                                  242                      38.72
# L12:Hemoglobin                               150                      24.00
# L13:Hematocrit                               139                      22.24
# L14:WBC                                      139                      22.24
# L15:Platelet                                 139                      22.24
# L16:TIBC                                     613                      98.08
# L17:Tranferin SAT                            614                      98.24
# L18:Ferritin                                 614                      98.24
# L19:Blood sugar                              387                      61.92
# L20:HbA1c                                    446                      71.36
# L21:Cholesterol                              225                      36.00
# L22:Triglyceride                             431                      68.96
# L23:LDL Cholesterol                          416                      66.56
# L24:HDL Cholesterol                          440                      70.40
# L25:Parathyroid hormone                      610                      97.60
# L26:Vitamin D                                602                      96.32
# L27:UrineAlbumin/Cr ratio                    622                      99.52
# L28:UrineProtein/Cr ratio                    558                      89.28
# L29:UrineVolume (24hrs)                      621                      99.36
# L30:UrineUrea (24hrs)                        621                      99.36
# L31:UrineSodium (24hrs)                      623                      99.68
# L32:UrineProtein (24hrs)                     620                      99.20

# %% [markdown]
# ##ระยะที่ 2

# %%
# ใช้ตัวกรองเพื่อเลือกข้อมูลที่มี 'eGFR_Category' เป็น 'ระยะที่ 2'
stage2 = data1[data1['eGFR_Category'] == 'Stage 2']
stage2 # 19996
# Out:
#        PatientUID     Slopes  Recent_eGFR eGFR_Category    BMI   BSA  \
# 7          854989  44.179221        76.10       Stage 2  29.20  1.75
# 14        2261796   3.920716        68.80       Stage 2  24.89  1.50
# 15        1167788  31.427793        74.70       Stage 2  21.83  1.62
# 16         622412   4.777487        88.20       Stage 2  22.49  1.75
# 20        2235293  14.901809        63.90       Stage 2  27.34  1.73
# ...           ...        ...          ...           ...    ...   ...
# 52606     2180110  -9.147643        72.45       Stage 2    NaN   NaN
# 52607     2180110   6.725197        72.45       Stage 2    NaN   NaN
# 52608     2180110  -4.828042        72.45       Stage 2  23.81  1.78
# 52609     2180110 -14.127763        72.45       Stage 2    NaN   NaN
# 52610     2180110 -13.205285        72.45       Stage 2  26.26  1.86
#
#        Diastolic BP  Systolic BP  L1:eGFR  L2:BUN  ...  L23:LDL Cholesterol  \
# 7              77.0        148.0    29.50    35.8  ...                 59.0
# 14             59.0        103.0    64.60    15.9  ...                 63.0
# 15             58.0        130.0    59.20     NaN  ...                  NaN
# 16             92.0        160.0    73.10    11.4  ...                  NaN
# 20             83.0        149.0    48.10    16.7  ...                  NaN
# ...             ...          ...      ...     ...  ...                  ...
# 52606           NaN          NaN   128.60     NaN  ...                  NaN
# 52607           NaN          NaN   118.50     NaN  ...                  NaN
# 52608          71.0        138.0   125.52    12.5  ...                  NaN
# 52609           NaN          NaN   120.52     NaN  ...                  NaN
# 52610          78.0        129.0   106.16     NaN  ...                  NaN
#
#        L24:HDL Cholesterol  L25:Parathyroid hormone  L26:Vitamin D  \
# 7                     70.0                      NaN            NaN
# 14                    30.0                      NaN            NaN
# 15                     NaN                      NaN            NaN
# 16                     NaN                      NaN            NaN
# 20                     NaN                      NaN            NaN
# ...                    ...                      ...            ...
# 52606                  NaN                      NaN            NaN
# 52607                  NaN                      NaN            NaN
# 52608                  NaN                      NaN            NaN
# 52609                  NaN                      NaN            NaN
# 52610                  NaN                      NaN            NaN
#
#        L27:UrineAlbumin/Cr ratio  L28:UrineProtein/Cr ratio  \
# 7                            NaN                        NaN
# 14                           NaN                        NaN
# 15                           NaN                        NaN
# 16                           NaN                        NaN
# 20                           NaN                        NaN
# ...                          ...                        ...
# 52606                        NaN                        NaN
# 52607                        NaN                       23.0
# 52608                        NaN                       11.0
# 52609                        NaN                      184.0
# 52610                        NaN                      269.0
#
#        L29:UrineVolume (24hrs)  L30:UrineUrea (24hrs)  \
# 7                          NaN                    NaN
# 14                         NaN                    NaN
# 15                         NaN                    NaN
# 16                         NaN                    NaN
# 20                         NaN                    NaN
# ...                        ...                    ...
# 52606                      NaN                    NaN
# 52607                      NaN                    NaN
# 52608                      NaN                    NaN
# 52609                      NaN                    NaN
# 52610                      NaN                    NaN
#
#        L31:UrineSodium (24hrs)  L32:UrineProtein (24hrs)
# 7                          NaN                       NaN
# 14                         NaN                       NaN
# 15                         NaN                       NaN
# 16                         NaN                       NaN
# 20                         NaN                       NaN
# ...                        ...                       ...
# 52606                      NaN                       NaN
# 52607                      NaN                       NaN
# 52608                      NaN                       NaN
# 52609                      NaN                       NaN
# 52610                      NaN                       NaN
#
# [13889 rows x 40 columns]

# %%
# คำนวณจำนวนค่าที่ขาดหายไปในแต่ละคอลัมน์
stage2_missing = stage2.isnull().sum()

# คำนวณเปอร์เซ็นต์ของค่าที่ขาดหายไปในแต่ละคอลัมน์
missing_percent = 100 * stage2_missing / len(stage2)

# สร้าง DataFrame ที่ประกอบด้วยจำนวนค่าที่ขาดหายไปและเปอร์เซ็นต์ของค่าที่ขาดหายไป
missing2 = pd.DataFrame({
    'Stage2_Missing Values': stage2_missing,
    'Stage2_Missing Values (%)': missing_percent.round(2)  # ปัดทศนิยมในคอลัมน์ 'Missing Values (%)' เป็น 2 ตำแหน่ง
})

# แสดงผลลัพธ์ DataFrame ที่ถูกเรียงลำดับ
missing2
# Out:
#                            Stage2_Missing Values  Stage2_Missing Values (%)
# PatientUID                                     0                       0.00
# Slopes                                         0                       0.00
# Recent_eGFR                                    0                       0.00
# eGFR_Category                                  0                       0.00
# BMI                                         3880                      27.94
# BSA                                         3884                      27.96
# Diastolic BP                                1835                      13.21
# Systolic BP                                 1822                      13.12
# L1:eGFR                                        1                       0.01
# L2:BUN                                      3959                      28.50
# L3:Creatinine                                  1                       0.01
# L4:Sodium                                   6416                      46.19
# L5:Potassium                                5749                      41.39
# L6:Chloride                                 6430                      46.30
# L7:Bicarbonate                              6390                      46.01
# L8:Uric                                    10621                      76.47
# L9:Calcium                                 11272                      81.16
# L10:Phosphorus                             11343                      81.67
# L11:Albumin                                 7963                      57.33
# L12:Hemoglobin                              6385                      45.97
# L13:Hematocrit                              6044                      43.52
# L14:WBC                                     6044                      43.52
# L15:Platelet                                6044                      43.52
# L16:TIBC                                   13718                      98.77
# L17:Tranferin SAT                          13741                      98.93
# L18:Ferritin                               13715                      98.75
# L19:Blood sugar                             6236                      44.90
# L20:HbA1c                                   7711                      55.52
# L21:Cholesterol                             4751                      34.21
# L22:Triglyceride                            6702                      48.25
# L23:LDL Cholesterol                         6061                      43.64
# L24:HDL Cholesterol                         6848                      49.31
# L25:Parathyroid hormone                    13725                      98.82
# L26:Vitamin D                              13598                      97.90
# L27:UrineAlbumin/Cr ratio                  13557                      97.61
# L28:UrineProtein/Cr ratio                  12649                      91.07
# L29:UrineVolume (24hrs)                    13823                      99.52
# L30:UrineUrea (24hrs)                      13831                      99.58
# L31:UrineSodium (24hrs)                    13861                      99.80
# L32:UrineProtein (24hrs)                   13797                      99.34

# %%
# สร้างตัวแปรเพื่อเก็บเฉพาะค่าว่าง
stage2_missing_values_only = missing2[missing2['Stage2_Missing Values'] > 0]

# แสดงผลลัพธ์ DataFrame ที่เก็บเฉพาะค่าว่าง
stage2_missing_values_only
# Out:
#                            Stage2_Missing Values  Stage2_Missing Values (%)
# BMI                                         3880                      27.94
# BSA                                         3884                      27.96
# Diastolic BP                                1835                      13.21
# Systolic BP                                 1822                      13.12
# L1:eGFR                                        1                       0.01
# L2:BUN                                      3959                      28.50
# L3:Creatinine                                  1                       0.01
# L4:Sodium                                   6416                      46.19
# L5:Potassium                                5749                      41.39
# L6:Chloride                                 6430                      46.30
# L7:Bicarbonate                              6390                      46.01
# L8:Uric                                    10621                      76.47
# L9:Calcium                                 11272                      81.16
# L10:Phosphorus                             11343                      81.67
# L11:Albumin                                 7963                      57.33
# L12:Hemoglobin                              6385                      45.97
# L13:Hematocrit                              6044                      43.52
# L14:WBC                                     6044                      43.52
# L15:Platelet                                6044                      43.52
# L16:TIBC                                   13718                      98.77
# L17:Tranferin SAT                          13741                      98.93
# L18:Ferritin                               13715                      98.75
# L19:Blood sugar                             6236                      44.90
# L20:HbA1c                                   7711                      55.52
# L21:Cholesterol                             4751                      34.21
# L22:Triglyceride                            6702                      48.25
# L23:LDL Cholesterol                         6061                      43.64
# L24:HDL Cholesterol                         6848                      49.31
# L25:Parathyroid hormone                    13725                      98.82
# L26:Vitamin D                              13598                      97.90
# L27:UrineAlbumin/Cr ratio                  13557                      97.61
# L28:UrineProtein/Cr ratio                  12649                      91.07
# L29:UrineVolume (24hrs)                    13823                      99.52
# L30:UrineUrea (24hrs)                      13831                      99.58
# L31:UrineSodium (24hrs)                    13861                      99.80
# L32:UrineProtein (24hrs)                   13797                      99.34

# %% [markdown]
# ##ระยะที่ 3a

# %%
# ใช้ตัวกรองเพื่อเลือกข้อมูลที่มี 'eGFR_Category' เป็น 'ระยะที่ 3'
stage3a = data1[data1['eGFR_Category'] == 'Stage 3a']
stage3a.shape
# Out:
# (21227, 40)

# %%
# คำนวณจำนวนค่าที่ขาดหายไปในแต่ละคอลัมน์
stage3a_missing = stage3a.isnull().sum()

# คำนวณเปอร์เซ็นต์ของค่าที่ขาดหายไปในแต่ละคอลัมน์
missing_percent = 100 * stage3a_missing / len(stage3a)

# สร้าง DataFrame ที่ประกอบด้วยจำนวนค่าที่ขาดหายไปและเปอร์เซ็นต์ของค่าที่ขาดหายไป
missing3a = pd.DataFrame({
    'Stage3a_Missing Values': stage3a_missing,
    'Stage3a_Missing Values (%)': missing_percent.round(2)  # ปัดทศนิยมในคอลัมน์ 'Missing Values (%)' เป็น 2 ตำแหน่ง
})
# สร้างตัวแปรเพื่อเก็บเฉพาะค่าว่าง
stage3a_missing_values_only = missing3a[missing3a['Stage3a_Missing Values'] > 0]

# แสดงผลลัพธ์ DataFrame ที่เก็บเฉพาะค่าว่าง
stage3a_missing_values_only
# Out:
#                            Stage3a_Missing Values  Stage3a_Missing Values (%)
# BMI                                          5759                       27.13
# BSA                                          5758                       27.13
# Diastolic BP                                 2930                       13.80
# Systolic BP                                  2920                       13.76
# L2:BUN                                       5622                       26.49
# L4:Sodium                                    9589                       45.17
# L5:Potassium                                 8537                       40.22
# L6:Chloride                                  9631                       45.37
# L7:Bicarbonate                               9567                       45.07
# L8:Uric                                     15640                       73.68
# L9:Calcium                                  17315                       81.57
# L10:Phosphorus                              17465                       82.28
# L11:Albumin                                 12882                       60.69
# L12:Hemoglobin                              10203                       48.07
# L13:Hematocrit                               9708                       45.73
# L14:WBC                                      9711                       45.75
# L15:Platelet                                 9711                       45.75
# L16:TIBC                                    21000                       98.93
# L17:Tranferin SAT                           21030                       99.07
# L18:Ferritin                                20985                       98.86
# L19:Blood sugar                              8922                       42.03
# L20:HbA1c                                   11181                       52.67
# L21:Cholesterol                              7287                       34.33
# L22:Triglyceride                             9712                       45.75
# L23:LDL Cholesterol                          8670                       40.84
# L24:HDL Cholesterol                          9898                       46.63
# L25:Parathyroid hormone                     20928                       98.59
# L26:Vitamin D                               20789                       97.94
# L27:UrineAlbumin/Cr ratio                   20660                       97.33
# L28:UrineProtein/Cr ratio                   19291                       90.88
# L29:UrineVolume (24hrs)                     21126                       99.52
# L30:UrineUrea (24hrs)                       21119                       99.49
# L31:UrineSodium (24hrs)                     21149                       99.63
# L32:UrineProtein (24hrs)                    21073                       99.27

# %% [markdown]
# ##ระยะที่ 3b

# %%
# ใช้ตัวกรองเพื่อเลือกข้อมูลที่มี 'eGFR_Category' เป็น 'ระยะที่ 3'
stage3b = data1[data1['eGFR_Category'] == 'Stage 3b']
stage3b.shape
# Out:
# (10088, 40)

# %%
# คำนวณจำนวนค่าที่ขาดหายไปในแต่ละคอลัมน์
stage3b_missing = stage3b.isnull().sum()

# คำนวณเปอร์เซ็นต์ของค่าที่ขาดหายไปในแต่ละคอลัมน์
missing_percent = 100 * stage3b_missing / len(stage3b)

# สร้าง DataFrame ที่ประกอบด้วยจำนวนค่าที่ขาดหายไปและเปอร์เซ็นต์ของค่าที่ขาดหายไป
missing3b = pd.DataFrame({
    'Stage3b_Missing Values': stage3b_missing,
    'Stage3b_Missing Values (%)': missing_percent.round(2)  # ปัดทศนิยมในคอลัมน์ 'Missing Values (%)' เป็น 2 ตำแหน่ง
})
# สร้างตัวแปรเพื่อเก็บเฉพาะค่าว่าง
stage3b_missing_values_only = missing3b[missing3b['Stage3b_Missing Values'] > 0]

# แสดงผลลัพธ์ DataFrame ที่เก็บเฉพาะค่าว่าง
stage3b_missing_values_only
# Out:
#                            Stage3b_Missing Values  Stage3b_Missing Values (%)
# BMI                                          3117                       30.90
# BSA                                          3123                       30.96
# Diastolic BP                                 1206                       11.95
# Systolic BP                                  1197                       11.87
# L2:BUN                                       2174                       21.55
# L4:Sodium                                    3549                       35.18
# L5:Potassium                                 3164                       31.36
# L6:Chloride                                  3558                       35.27
# L7:Bicarbonate                               3534                       35.03
# L8:Uric                                      7380                       73.16
# L9:Calcium                                   7520                       74.54
# L10:Phosphorus                               7596                       75.30
# L11:Albumin                                  5809                       57.58
# L12:Hemoglobin                               4562                       45.22
# L13:Hematocrit                               4290                       42.53
# L14:WBC                                      4291                       42.54
# L15:Platelet                                 4291                       42.54
# L16:TIBC                                     9905                       98.19
# L17:Tranferin SAT                            9929                       98.42
# L18:Ferritin                                 9909                       98.23
# L19:Blood sugar                              4555                       45.15
# L20:HbA1c                                    5089                       50.45
# L21:Cholesterol                              3847                       38.13
# L22:Triglyceride                             5271                       52.25
# L23:LDL Cholesterol                          4725                       46.84
# L24:HDL Cholesterol                          5354                       53.07
# L25:Parathyroid hormone                      9897                       98.11
# L26:Vitamin D                                9829                       97.43
# L27:UrineAlbumin/Cr ratio                    9806                       97.20
# L28:UrineProtein/Cr ratio                    8966                       88.88
# L29:UrineVolume (24hrs)                     10032                       99.44
# L30:UrineUrea (24hrs)                       10025                       99.38
# L31:UrineSodium (24hrs)                     10041                       99.53
# L32:UrineProtein (24hrs)                     9991                       99.04

# %% [markdown]
# ##ระยะที่ 4

# %%
# ใช้ตัวกรองเพื่อเลือกข้อมูลที่มี 'eGFR_Category' เป็น 'ระยะที่ 4'
stage4 = data1[data1['eGFR_Category'] == 'Stage 4']
stage4.shape
# Out:
# (4239, 40)

# %%
# คำนวณจำนวนค่าที่ขาดหายไปในแต่ละคอลัมน์
stage4_missing = stage4.isnull().sum()

# คำนวณเปอร์เซ็นต์ของค่าที่ขาดหายไปในแต่ละคอลัมน์
missing_percent = 100 * stage4_missing / len(stage4)

# สร้าง DataFrame ที่ประกอบด้วยจำนวนค่าที่ขาดหายไปและเปอร์เซ็นต์ของค่าที่ขาดหายไป
missing4 = pd.DataFrame({
    'Stage4_Missing Values': stage4_missing,
    'Stage4_Missing Values (%)': missing_percent.round(2)  # ปัดทศนิยมในคอลัมน์ 'Missing Values (%)' เป็น 2 ตำแหน่ง
})
# สร้างตัวแปรเพื่อเก็บเฉพาะค่าว่าง
stage4_missing_values_only = missing4[missing4['Stage4_Missing Values'] > 0]

# แสดงผลลัพธ์ DataFrame ที่เก็บเฉพาะค่าว่าง
stage4_missing_values_only
# Out:
#                            Stage4_Missing Values  Stage4_Missing Values (%)
# BMI                                         1483                      34.98
# BSA                                         1480                      34.91
# Diastolic BP                                 495                      11.68
# Systolic BP                                  490                      11.56
# L2:BUN                                       661                      15.59
# L4:Sodium                                   1029                      24.27
# L5:Potassium                                 933                      22.01
# L6:Chloride                                 1041                      24.56
# L7:Bicarbonate                              1023                      24.13
# L8:Uric                                     2964                      69.92
# L9:Calcium                                  2638                      62.23
# L10:Phosphorus                              2669                      62.96
# L11:Albumin                                 2019                      47.63
# L12:Hemoglobin                              1578                      37.23
# L13:Hematocrit                              1452                      34.25
# L14:WBC                                     1452                      34.25
# L15:Platelet                                1452                      34.25
# L16:TIBC                                    4111                      96.98
# L17:Tranferin SAT                           4126                      97.33
# L18:Ferritin                                4106                      96.86
# L19:Blood sugar                             1942                      45.81
# L20:HbA1c                                   2151                      50.74
# L21:Cholesterol                             1724                      40.67
# L22:Triglyceride                            2457                      57.96
# L23:LDL Cholesterol                         2126                      50.15
# L24:HDL Cholesterol                         2453                      57.87
# L25:Parathyroid hormone                     4143                      97.74
# L26:Vitamin D                               4106                      96.86
# L27:UrineAlbumin/Cr ratio                   4149                      97.88
# L28:UrineProtein/Cr ratio                   3551                      83.77
# L29:UrineVolume (24hrs)                     4177                      98.54
# L30:UrineUrea (24hrs)                       4164                      98.23
# L31:UrineSodium (24hrs)                     4175                      98.49
# L32:UrineProtein (24hrs)                    4138                      97.62

# %% [markdown]
# #ระยะที่ 5

# %%
# ใช้ตัวกรองเพื่อเลือกข้อมูลที่มี 'eGFR_Category' เป็น 'ระยะที่ 5'
stage5 = data1[data1['eGFR_Category'] == 'Stage 5']
stage5.shape
# Out:
# (2552, 40)

# %%
# คำนวณจำนวนค่าที่ขาดหายไปในแต่ละคอลัมน์
stage5_missing = stage5.isnull().sum()

# คำนวณเปอร์เซ็นต์ของค่าที่ขาดหายไปในแต่ละคอลัมน์
missing_percent = 100 * stage5_missing / len(stage5)

# สร้าง DataFrame ที่ประกอบด้วยจำนวนค่าที่ขาดหายไปและเปอร์เซ็นต์ของค่าที่ขาดหายไป
missing5 = pd.DataFrame({
    'Stage5_Missing Values': stage5_missing,
    'Stage5_Missing Values (%)': missing_percent.round(2)  # ปัดทศนิยมในคอลัมน์ 'Missing Values (%)' เป็น 2 ตำแหน่ง
})
# สร้างตัวแปรเพื่อเก็บเฉพาะค่าว่าง
stage5_missing_values_only = missing5[missing5['Stage5_Missing Values'] > 0]

# แสดงผลลัพธ์ DataFrame ที่เก็บเฉพาะค่าว่าง
stage5_missing_values_only
# Out:
#                            Stage5_Missing Values  Stage5_Missing Values (%)
# BMI                                          877                      34.37
# BSA                                          880                      34.48
# Diastolic BP                                 297                      11.64
# Systolic BP                                  293                      11.48
# L2:BUN                                       289                      11.32
# L4:Sodium                                    480                      18.81
# L5:Potassium                                 431                      16.89
# L6:Chloride                                  484                      18.97
# L7:Bicarbonate                               471                      18.46
# L8:Uric                                     1762                      69.04
# L9:Calcium                                  1271                      49.80
# L10:Phosphorus                              1272                      49.84
# L11:Albumin                                  995                      38.99
# L12:Hemoglobin                               734                      28.76
# L13:Hematocrit                               677                      26.53
# L14:WBC                                      677                      26.53
# L15:Platelet                                 677                      26.53
# L16:TIBC                                    2389                      93.61
# L17:Tranferin SAT                           2411                      94.47
# L18:Ferritin                                2396                      93.89
# L19:Blood sugar                             1261                      49.41
# L20:HbA1c                                   1407                      55.13
# L21:Cholesterol                             1140                      44.67
# L22:Triglyceride                            1647                      64.54
# L23:LDL Cholesterol                         1397                      54.74
# L24:HDL Cholesterol                         1633                      63.99
# L25:Parathyroid hormone                     2434                      95.38
# L26:Vitamin D                               2426                      95.06
# L27:UrineAlbumin/Cr ratio                   2522                      98.82
# L28:UrineProtein/Cr ratio                   2137                      83.74
# L29:UrineVolume (24hrs)                     2501                      98.00
# L30:UrineUrea (24hrs)                       2464                      96.55
# L31:UrineSodium (24hrs)                     2487                      97.45
# L32:UrineProtein (24hrs)                    2490                      97.57

# %% [markdown]
# #สร้างตารางรวมทุกระยะ

# %%
# สร้างตารางที่รวมกันแนวคอลัมน์
combined_missing_values = pd.concat([
    stage1_missing_values_only,
    stage2_missing_values_only,
    stage3a_missing_values_only,
    stage3b_missing_values_only,
    stage4_missing_values_only,
    stage5_missing_values_only
], axis=1)

# แสดงผลลัพธ์ของตารางที่รวมกัน
combined_missing_values
# Out:
#                            Stage1_Missing Values  Stage1_Missing Values (%)  \
# BMI                                        223.0                      35.68
# BSA                                        224.0                      35.84
# Diastolic BP                                79.0                      12.64
# Systolic BP                                 79.0                      12.64
# L2:BUN                                     135.0                      21.60
# L4:Sodium                                  220.0                      35.20
# L5:Potassium                               205.0                      32.80
# L6:Chloride                                220.0                      35.20
# L7:Bicarbonate                             219.0                      35.04
# L8:Uric                                    531.0                      84.96
# L9:Calcium                                 428.0                      68.48
# L10:Phosphorus                             434.0                      69.44
# L11:Albumin                                242.0                      38.72
# L12:Hemoglobin                             150.0                      24.00
# L13:Hematocrit                             139.0                      22.24
# L14:WBC                                    139.0                      22.24
# L15:Platelet                               139.0                      22.24
# L16:TIBC                                   613.0                      98.08
# L17:Tranferin SAT                          614.0                      98.24
# L18:Ferritin                               614.0                      98.24
# L19:Blood sugar                            387.0                      61.92
# L20:HbA1c                                  446.0                      71.36
# L21:Cholesterol                            225.0                      36.00
# L22:Triglyceride                           431.0                      68.96
# L23:LDL Cholesterol                        416.0                      66.56
# L24:HDL Cholesterol                        440.0                      70.40
# L25:Parathyroid hormone                    610.0                      97.60
# L26:Vitamin D                              602.0                      96.32
# L27:UrineAlbumin/Cr ratio                  622.0                      99.52
# L28:UrineProtein/Cr ratio                  558.0                      89.28
# L29:UrineVolume (24hrs)                    621.0                      99.36
# L30:UrineUrea (24hrs)                      621.0                      99.36
# L31:UrineSodium (24hrs)                    623.0                      99.68
# L32:UrineProtein (24hrs)                   620.0                      99.20
# L1:eGFR                                      NaN                        NaN
# L3:Creatinine                                NaN                        NaN
#
#                            Stage2_Missing Values  Stage2_Missing Values (%)  \
# BMI                                         3880                      27.94
# BSA                                         3884                      27.96
# Diastolic BP                                1835                      13.21
# Systolic BP                                 1822                      13.12
# L2:BUN                                      3959                      28.50
# L4:Sodium                                   6416                      46.19
# L5:Potassium                                5749                      41.39
# L6:Chloride                                 6430                      46.30
# L7:Bicarbonate                              6390                      46.01
# L8:Uric                                    10621                      76.47
# L9:Calcium                                 11272                      81.16
# L10:Phosphorus                             11343                      81.67
# L11:Albumin                                 7963                      57.33
# L12:Hemoglobin                              6385                      45.97
# L13:Hematocrit                              6044                      43.52
# L14:WBC                                     6044                      43.52
# L15:Platelet                                6044                      43.52
# L16:TIBC                                   13718                      98.77
# L17:Tranferin SAT                          13741                      98.93
# L18:Ferritin                               13715                      98.75
# L19:Blood sugar                             6236                      44.90
# L20:HbA1c                                   7711                      55.52
# L21:Cholesterol                             4751                      34.21
# L22:Triglyceride                            6702                      48.25
# L23:LDL Cholesterol                         6061                      43.64
# L24:HDL Cholesterol                         6848                      49.31
# L25:Parathyroid hormone                    13725                      98.82
# L26:Vitamin D                              13598                      97.90
# L27:UrineAlbumin/Cr ratio                  13557                      97.61
# L28:UrineProtein/Cr ratio                  12649                      91.07
# L29:UrineVolume (24hrs)                    13823                      99.52
# L30:UrineUrea (24hrs)                      13831                      99.58
# L31:UrineSodium (24hrs)                    13861                      99.80
# L32:UrineProtein (24hrs)                   13797                      99.34
# L1:eGFR                                        1                       0.01
# L3:Creatinine                                  1                       0.01
#
#                            Stage3a_Missing Values  Stage3a_Missing Values (%)  \
# BMI                                        5759.0                       27.13
# BSA                                        5758.0                       27.13
# Diastolic BP                               2930.0                       13.80
# Systolic BP                                2920.0                       13.76
# L2:BUN                                     5622.0                       26.49
# L4:Sodium                                  9589.0                       45.17
# L5:Potassium                               8537.0                       40.22
# L6:Chloride                                9631.0                       45.37
# L7:Bicarbonate                             9567.0                       45.07
# L8:Uric                                   15640.0                       73.68
# L9:Calcium                                17315.0                       81.57
# L10:Phosphorus                            17465.0                       82.28
# L11:Albumin                               12882.0                       60.69
# L12:Hemoglobin                            10203.0                       48.07
# L13:Hematocrit                             9708.0                       45.73
# L14:WBC                                    9711.0                       45.75
# L15:Platelet                               9711.0                       45.75
# L16:TIBC                                  21000.0                       98.93
# L17:Tranferin SAT                         21030.0                       99.07
# L18:Ferritin                              20985.0                       98.86
# L19:Blood sugar                            8922.0                       42.03
# L20:HbA1c                                 11181.0                       52.67
# L21:Cholesterol                            7287.0                       34.33
# L22:Triglyceride                           9712.0                       45.75
# L23:LDL Cholesterol                        8670.0                       40.84
# L24:HDL Cholesterol                        9898.0                       46.63
# L25:Parathyroid hormone                   20928.0                       98.59
# L26:Vitamin D                             20789.0                       97.94
# L27:UrineAlbumin/Cr ratio                 20660.0                       97.33
# L28:UrineProtein/Cr ratio                 19291.0                       90.88
# L29:UrineVolume (24hrs)                   21126.0                       99.52
# L30:UrineUrea (24hrs)                     21119.0                       99.49
# L31:UrineSodium (24hrs)                   21149.0                       99.63
# L32:UrineProtein (24hrs)                  21073.0                       99.27
# L1:eGFR                                       NaN                         NaN
# L3:Creatinine                                 NaN                         NaN
#
#                            Stage3b_Missing Values  Stage3b_Missing Values (%)  \
# BMI                                        3117.0                       30.90
# BSA                                        3123.0                       30.96
# Diastolic BP                               1206.0                       11.95
# Systolic BP                                1197.0                       11.87
# L2:BUN                                     2174.0                       21.55
# L4:Sodium                                  3549.0                       35.18
# L5:Potassium                               3164.0                       31.36
# L6:Chloride                                3558.0                       35.27
# L7:Bicarbonate                             3534.0                       35.03
# L8:Uric                                    7380.0                       73.16
# L9:Calcium                                 7520.0                       74.54
# L10:Phosphorus                             7596.0                       75.30
# L11:Albumin                                5809.0                       57.58
# L12:Hemoglobin                             4562.0                       45.22
# L13:Hematocrit                             4290.0                       42.53
# L14:WBC                                    4291.0                       42.54
# L15:Platelet                               4291.0                       42.54
# L16:TIBC                                   9905.0                       98.19
# L17:Tranferin SAT                          9929.0                       98.42
# L18:Ferritin                               9909.0                       98.23
# L19:Blood sugar                            4555.0                       45.15
# L20:HbA1c                                  5089.0                       50.45
# L21:Cholesterol                            3847.0                       38.13
# L22:Triglyceride                           5271.0                       52.25
# L23:LDL Cholesterol                        4725.0                       46.84
# L24:HDL Cholesterol                        5354.0                       53.07
# L25:Parathyroid hormone                    9897.0                       98.11
# L26:Vitamin D                              9829.0                       97.43
# L27:UrineAlbumin/Cr ratio                  9806.0                       97.20
# L28:UrineProtein/Cr ratio                  8966.0                       88.88
# L29:UrineVolume (24hrs)                   10032.0                       99.44
# L30:UrineUrea (24hrs)                     10025.0                       99.38
# L31:UrineSodium (24hrs)                   10041.0                       99.53
# L32:UrineProtein (24hrs)                   9991.0                       99.04
# L1:eGFR                                       NaN                         NaN
# L3:Creatinine                                 NaN                         NaN
#
#                            Stage4_Missing Values  Stage4_Missing Values (%)  \
# BMI                                       1483.0                      34.98
# BSA                                       1480.0                      34.91
# Diastolic BP                               495.0                      11.68
# Systolic BP                                490.0                      11.56
# L2:BUN                                     661.0                      15.59
# L4:Sodium                                 1029.0                      24.27
# L5:Potassium                               933.0                      22.01
# L6:Chloride                               1041.0                      24.56
# L7:Bicarbonate                            1023.0                      24.13
# L8:Uric                                   2964.0                      69.92
# L9:Calcium                                2638.0                      62.23
# L10:Phosphorus                            2669.0                      62.96
# L11:Albumin                               2019.0                      47.63
# L12:Hemoglobin                            1578.0                      37.23
# L13:Hematocrit                            1452.0                      34.25
# L14:WBC                                   1452.0                      34.25
# L15:Platelet                              1452.0                      34.25
# L16:TIBC                                  4111.0                      96.98
# L17:Tranferin SAT                         4126.0                      97.33
# L18:Ferritin                              4106.0                      96.86
# L19:Blood sugar                           1942.0                      45.81
# L20:HbA1c                                 2151.0                      50.74
# L21:Cholesterol                           1724.0                      40.67
# L22:Triglyceride                          2457.0                      57.96
# L23:LDL Cholesterol                       2126.0                      50.15
# L24:HDL Cholesterol                       2453.0                      57.87
# L25:Parathyroid hormone                   4143.0                      97.74
# L26:Vitamin D                             4106.0                      96.86
# L27:UrineAlbumin/Cr ratio                 4149.0                      97.88
# L28:UrineProtein/Cr ratio                 3551.0                      83.77
# L29:UrineVolume (24hrs)                   4177.0                      98.54
# L30:UrineUrea (24hrs)                     4164.0                      98.23
# L31:UrineSodium (24hrs)                   4175.0                      98.49
# L32:UrineProtein (24hrs)                  4138.0                      97.62
# L1:eGFR                                      NaN                        NaN
# L3:Creatinine                                NaN                        NaN
#
#                            Stage5_Missing Values  Stage5_Missing Values (%)
# BMI                                        877.0                      34.37
# BSA                                        880.0                      34.48
# Diastolic BP                               297.0                      11.64
# Systolic BP                                293.0                      11.48
# L2:BUN                                     289.0                      11.32
# L4:Sodium                                  480.0                      18.81
# L5:Potassium                               431.0                      16.89
# L6:Chloride                                484.0                      18.97
# L7:Bicarbonate                             471.0                      18.46
# L8:Uric                                   1762.0                      69.04
# L9:Calcium                                1271.0                      49.80
# L10:Phosphorus                            1272.0                      49.84
# L11:Albumin                                995.0                      38.99
# L12:Hemoglobin                             734.0                      28.76
# L13:Hematocrit                             677.0                      26.53
# L14:WBC                                    677.0                      26.53
# L15:Platelet                               677.0                      26.53
# L16:TIBC                                  2389.0                      93.61
# L17:Tranferin SAT                         2411.0                      94.47
# L18:Ferritin                              2396.0                      93.89
# L19:Blood sugar                           1261.0                      49.41
# L20:HbA1c                                 1407.0                      55.13
# L21:Cholesterol                           1140.0                      44.67
# L22:Triglyceride                          1647.0                      64.54
# L23:LDL Cholesterol                       1397.0                      54.74
# L24:HDL Cholesterol                       1633.0                      63.99
# L25:Parathyroid hormone                   2434.0                      95.38
# L26:Vitamin D                             2426.0                      95.06
# L27:UrineAlbumin/Cr ratio                 2522.0                      98.82
# L28:UrineProtein/Cr ratio                 2137.0                      83.74
# L29:UrineVolume (24hrs)                   2501.0                      98.00
# L30:UrineUrea (24hrs)                     2464.0                      96.55
# L31:UrineSodium (24hrs)                   2487.0                      97.45
# L32:UrineProtein (24hrs)                  2490.0                      97.57
# L1:eGFR                                      NaN                        NaN
# L3:Creatinine                                NaN                        NaN

# %% [markdown]
# #ทำ Visualization ด้วย Heatmap ตามค่า eGFR_Category

# %%
#จากมากไปน้อย
stage_sort = data1.sort_values(by='Recent_eGFR', ascending=False)
stage_sort.head()
# Out:
#        PatientUID     Slopes  Recent_eGFR eGFR_Category    BMI   BSA  \
# 51783      553538   0.058871       140.75       Stage 1  18.88  1.20
# 51784      553538 -51.636256       140.75       Stage 1    NaN   NaN
# 5319      2384626   0.795640       125.93       Stage 1    NaN   NaN
# 5318      2384626   7.984375       125.93       Stage 1  23.31  1.54
# 5317      2384626  79.441176       125.93       Stage 1    NaN   NaN
#
#        Diastolic BP  Systolic BP  L1:eGFR  L2:BUN  ...  L23:LDL Cholesterol  \
# 51783          68.0        108.0   142.68     5.8  ...                  NaN
# 51784          67.0        103.0   142.74     NaN  ...                  NaN
# 5319           99.0        144.0   108.50    11.9  ...                  NaN
# 5318           93.0        132.0   100.10     9.9  ...                  NaN
# 5317           86.0        152.0    42.50    42.7  ...                  NaN
#
#        L24:HDL Cholesterol  L25:Parathyroid hormone  L26:Vitamin D  \
# 51783                  NaN                      NaN            NaN
# 51784                  NaN                      NaN            NaN
# 5319                   NaN                      NaN            NaN
# 5318                   NaN                      NaN            NaN
# 5317                   NaN                      NaN            NaN
#
#        L27:UrineAlbumin/Cr ratio  L28:UrineProtein/Cr ratio  \
# 51783                        NaN                        NaN
# 51784                        NaN                        NaN
# 5319                         NaN                        NaN
# 5318                         NaN                        NaN
# 5317                         NaN                       87.0
#
#        L29:UrineVolume (24hrs)  L30:UrineUrea (24hrs)  \
# 51783                      NaN                    NaN
# 51784                      NaN                    NaN
# 5319                       NaN                    NaN
# 5318                       NaN                    NaN
# 5317                       NaN                    NaN
#
#        L31:UrineSodium (24hrs)  L32:UrineProtein (24hrs)
# 51783                      NaN                       NaN
# 51784                      NaN                       NaN
# 5319                       NaN                       NaN
# 5318                       NaN                       NaN
# 5317                       NaN                       NaN
#
# [5 rows x 40 columns]

# %%
# นับค่าว่างและค่าไม่ว่างของแต่ละคอลัมน์
missing_values = stage_sort.isnull().sum()
non_missing_values = stage_sort.notnull().sum()

# สร้าง DataFrame ของค่าว่างและค่าไม่ว่าง
missing_non_missing_df = pd.DataFrame({'Missing Values': missing_values, 'Non-Missing Values': non_missing_values})
missing_non_missing_df
# Out:
#                            Missing Values  Non-Missing Values
# PatientUID                              0               52620
# Slopes                                  0               52620
# Recent_eGFR                             0               52620
# eGFR_Category                           0               52620
# BMI                                 15339               37281
# BSA                                 15349               37271
# Diastolic BP                         6842               45778
# Systolic BP                          6801               45819
# L1:eGFR                                 1               52619
# L2:BUN                              12840               39780
# L3:Creatinine                           1               52619
# L4:Sodium                           21283               31337
# L5:Potassium                        19019               33601
# L6:Chloride                         21364               31256
# L7:Bicarbonate                      21204               31416
# L8:Uric                             38898               13722
# L9:Calcium                          40444               12176
# L10:Phosphorus                      40779               11841
# L11:Albumin                         29910               22710
# L12:Hemoglobin                      23612               29008
# L13:Hematocrit                      22310               30310
# L14:WBC                             22314               30306
# L15:Platelet                        22314               30306
# L16:TIBC                            51736                 884
# L17:Tranferin SAT                   51851                 769
# L18:Ferritin                        51725                 895
# L19:Blood sugar                     23303               29317
# L20:HbA1c                           27985               24635
# L21:Cholesterol                     18974               33646
# L22:Triglyceride                    26220               26400
# L23:LDL Cholesterol                 23395               29225
# L24:HDL Cholesterol                 26626               25994
# L25:Parathyroid hormone             51737                 883
# L26:Vitamin D                       51350                1270
# L27:UrineAlbumin/Cr ratio           51316                1304
# L28:UrineProtein/Cr ratio           47152                5468
# L29:UrineVolume (24hrs)             52280                 340
# L30:UrineUrea (24hrs)               52224                 396
# L31:UrineSodium (24hrs)             52336                 284
# L32:UrineProtein (24hrs)            52109                 511

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Count missing and non-missing values for each column by 'eGFR_Category'
missing_non_missing_count = stage_sort.groupby('eGFR_Category').apply(lambda x: x.isnull().mean() * 100)

# Transpose the DataFrame for better visualization
missing_non_missing_count = missing_non_missing_count.T

# Plotting the missing and non-missing counts as percentages
plt.figure(figsize=(12, 8))
sns.heatmap(missing_non_missing_count, cmap='viridis', annot=True, fmt='.2f', cbar_kws={'label': 'Percentage of Missing Values'})

plt.title('Percentage of Missing Values by eGFR_Category for Each Variable')
plt.xlabel('eGFR Category')
plt.ylabel('Variables')
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Count missing and non-missing values for each column by 'eGFR_Category'
missing_non_missing_count = stage_sort.isnull().groupby(stage_sort['eGFR_Category']).sum()

# Plotting the missing and non-missing counts separately for each eGFR_Category
plt.figure(figsize=(20, 15))

unique_stages = missing_non_missing_count.index.unique()

for i, stage in enumerate(unique_stages):
    plt.subplot(2, len(unique_stages) // 2, i + 1)
    sns.heatmap(missing_non_missing_count.loc[stage].to_frame(), cmap='viridis', annot=True, fmt='g', cbar_kws={'label': 'Number of Missing Values'})
    plt.title(f'Missing Values in {stage}')
    plt.xlabel('Variables')
    plt.ylabel('eGFR Category')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Your combined_missing_values DataFrame with index as variables and columns as Stage names

# Plotting Heatmaps for each Stage based on the count of missing values

plt.figure(figsize=(30, 25))

unique_stages = combined_missing_values.columns

for i, stage in enumerate(unique_stages):
    plt.subplot(2, len(unique_stages) // 2, i + 1)
    sns.heatmap(combined_missing_values[[stage]], cmap='viridis', annot=True, fmt='.2f', cbar_kws={'label': 'Number of Missing Values'})
    plt.title(f'Missing Values in {stage}')
    plt.xlabel('Variables')
    plt.ylabel('')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Define the two groups of stage columns
stage_columns_count = ['Stage1_Missing Values', 'Stage2_Missing Values', 'Stage3a_Missing Values', 'Stage3b_Missing Values', 'Stage4_Missing Values', 'Stage5_Missing Values']

# Plotting Heatmaps for each group of columns
plt.figure(figsize=(20, 15))

# Plotting Heatmap for missing values count by stage
for i, stage in enumerate(stage_columns_count):
    plt.subplot(2, len(stage_columns_count) // 2, i + 1)
    sns.heatmap(combined_missing_values[[stage]], cmap='viridis', annot=True, fmt='g', cbar_kws={'label': 'Number of Missing Values'})
    plt.title(f'Missing Values Count in {stage}')
    plt.xlabel('Variables')
    plt.ylabel('')

plt.tight_layout()
plt.show()

# %%
stage_columns_percentage = ['Stage1_Missing Values (%)', 'Stage2_Missing Values (%)', 'Stage3a_Missing Values (%)', 'Stage3b_Missing Values (%)', 'Stage4_Missing Values (%)', 'Stage5_Missing Values (%)']
# Plotting Heatmap for missing values percentage by stage
plt.figure(figsize=(20, 15))
for i, stage in enumerate(stage_columns_percentage):
    plt.subplot(2, len(stage_columns_percentage) // 2, i + 1)
    sns.heatmap(combined_missing_values[[stage]], cmap='viridis', annot=True, fmt='.2f', cbar_kws={'label': 'Percentage of Missing Values'})
    plt.title(f'Missing Values Percentage in {stage}')
    plt.xlabel('Variables')
    plt.ylabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# #แบ่งตามค่า slope

# %% [markdown]
# โดยแบ่งออกเป็น
# * better คือ >-0.5
# * worse คือ <=-0.5

# %%
df
# Out:
#        Unnamed: 0  PatientUID  Recent_Creatinine  Recent_eGFR  \
# 0               0      924852               2.63        15.80
# 1               1      989278               2.03        32.30
# 2               2     2103792               1.05        55.90
# 3               3      953611               1.03        51.10
# 4               4      488150               1.94        32.60
# ...           ...         ...                ...          ...
# 52615       52615       43763               1.30        55.28
# 52616       52616       43763               1.30        55.28
# 52617       52617       43763               1.30        55.28
# 52618       52618       43763               1.30        55.28
# 52619       52619       43763               1.30        55.28
#
#                    Recent_Date  PatientVisitUID     Slopes  G1M2:ARB  \
# 0      2560-08-07 12:32:50.527          3349148   2.754717         0
# 1      2560-08-11 08:22:48.737          3348711 -46.720000         0
# 2      2560-08-14 14:38:44.150          3369057  11.018868         0
# 3      2560-08-15 02:05:01.323          3366405  17.222520         0
# 4      2560-08-15 09:18:43.240          3356167 -79.002653         0
# ...                        ...              ...        ...       ...
# 52615  2566-04-10 15:34:20.643          4553420  -4.929870         0
# 52616  2566-04-10 15:34:20.643          5674644  16.017287         0
# 52617  2566-04-10 15:34:20.643          6817059 -24.861814         0
# 52618  2566-04-10 15:34:20.643          8004571   4.558175         0
# 52619  2566-04-10 15:34:20.643          9214741   2.708378         0
#
#        G3M1:Statin  G5M2:NSAIDs  ...  L25:Parathyroid hormone  L26:Vitamin D  \
# 0               30            0  ...                      NaN            NaN
# 1                0            0  ...                      NaN            NaN
# 2                0            0  ...                      NaN            NaN
# 3                0            0  ...                      NaN            NaN
# 4                0            0  ...                      NaN            NaN
# ...            ...          ...  ...                      ...            ...
# 52615           90            0  ...                      NaN            NaN
# 52616           90            0  ...                      NaN            NaN
# 52617            0            0  ...                      NaN            NaN
# 52618            0            0  ...                      NaN            NaN
# 52619          100            0  ...                      NaN            NaN
#
#        L27:UrineAlbumin/Cr ratio  L28:UrineProtein/Cr ratio  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                       17.0
# ...                          ...                        ...
# 52615                        NaN                        NaN
# 52616                        NaN                        NaN
# 52617                        NaN                        NaN
# 52618                        NaN                        NaN
# 52619                        NaN                        NaN
#
#        L29:UrineVolume (24hrs)  L30:UrineUrea (24hrs)  \
# 0                          NaN                    NaN
# 1                          NaN                    NaN
# 2                          NaN                    NaN
# 3                          NaN                    NaN
# 4                          NaN                    NaN
# ...                        ...                    ...
# 52615                      NaN                    NaN
# 52616                      NaN                    NaN
# 52617                      NaN                    NaN
# 52618                      NaN                    NaN
# 52619                      NaN                    NaN
#
#        L31:UrineSodium (24hrs)  L32:UrineProtein (24hrs)  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ...                        ...                       ...
# 52615                      NaN                       NaN
# 52616                      NaN                       NaN
# 52617                      NaN                       NaN
# 52618                      NaN                       NaN
# 52619                      NaN                       NaN
#
#                                      LabLocation                 LabCwhen
# 0      ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร  2559-08-01 08:15:57.943
# 1                ห้องปฏิบัติการจุลทรรศน์วินิจฉัย  2559-08-01 09:14:12.527
# 2      ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร  2559-08-08 09:42:53.923
# 3                ห้องปฏิบัติการจุลทรรศน์วินิจฉัย  2559-08-06 10:35:19.840
# 4      ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร  2559-08-03 08:44:33.377
# ...                                          ...                      ...
# 52615  ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร  2560-10-05 08:55:06.223
# 52616  ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร  2561-10-25 09:43:02.440
# 52617  ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร  2562-11-06 09:08:22.770
# 52618  ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร  2563-12-29 10:39:32.263
# 52619  ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร  2565-02-25 08:17:16.137
#
# [52620 rows x 94 columns]

# %%
# สร้างตัวแปรมาเก็บค่า Missing โดยรวม "PatientUID", "Slopes", "Recent_eGFR"
missing_columns = df.columns[(df.isnull().any()) | (df.columns.isin([ "PatientUID", "Slopes", "Recent_eGFR"]))].tolist()
# สร้าง DataFrame ที่มีเฉพาะคอลัมน์ที่มีค่าที่หายไป
slope = df[missing_columns]
slope.head() #36 คอลัมน์ที่มีค่าว่าง
# Out:
#    PatientUID  Recent_eGFR     Slopes    BMI   BSA  Diastolic BP  Systolic BP  \
# 0      924852         15.8   2.754717    NaN   NaN          53.0        131.0
# 1      989278         32.3 -46.720000  18.71  1.70          71.0        121.0
# 2     2103792         55.9  11.018868  23.56  1.47          93.0        143.0
# 3      953611         51.1  17.222520  27.50  1.41          60.0        120.0
# 4      488150         32.6 -79.002653    NaN   NaN           NaN          NaN
#
#    L1:eGFR  L2:BUN  L3:Creatinine  ...  L23:LDL Cholesterol  \
# 0     13.0     NaN            3.1  ...                  NaN
# 1     80.3     5.2            1.0  ...                  NaN
# 2     44.7    22.6            1.3  ...                  NaN
# 3     33.5    28.9            1.5  ...                147.0
# 4    114.2     NaN            0.7  ...                  NaN
#
#    L24:HDL Cholesterol  L25:Parathyroid hormone  L26:Vitamin D  \
# 0                  NaN                      NaN            NaN
# 1                  NaN                      NaN            NaN
# 2                  NaN                      NaN            NaN
# 3                 30.0                      NaN            NaN
# 4                  NaN                      NaN            NaN
#
#    L27:UrineAlbumin/Cr ratio  L28:UrineProtein/Cr ratio  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                       17.0
#
#    L29:UrineVolume (24hrs)  L30:UrineUrea (24hrs)  L31:UrineSodium (24hrs)  \
# 0                      NaN                    NaN                      NaN
# 1                      NaN                    NaN                      NaN
# 2                      NaN                    NaN                      NaN
# 3                      NaN                    NaN                      NaN
# 4                      NaN                    NaN                      NaN
#
#    L32:UrineProtein (24hrs)
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 39 columns]

# %%
# สร้างฟังก์ชันสำหรับแบ่งข้อมูลตาม Slopes
def categorize_slope(slope):
    if slope >-0.5:
        return 'better'
    else:
        return 'worse'

# เพิ่มคอลัมน์ 'eGFR_Category' ที่บอกระดับของ 'Recent_eGFR'
slope['slope_Category'] = slope['Slopes'].apply(categorize_slope)
slope.head()
# Out:
# <ipython-input-53-2f9d2557905f>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   slope['slope_Category'] = slope['Slopes'].apply(categorize_slope)
#    PatientUID  Recent_eGFR     Slopes    BMI   BSA  Diastolic BP  Systolic BP  \
# 0      924852         15.8   2.754717    NaN   NaN          53.0        131.0
# 1      989278         32.3 -46.720000  18.71  1.70          71.0        121.0
# 2     2103792         55.9  11.018868  23.56  1.47          93.0        143.0
# 3      953611         51.1  17.222520  27.50  1.41          60.0        120.0
# 4      488150         32.6 -79.002653    NaN   NaN           NaN          NaN
#
#    L1:eGFR  L2:BUN  L3:Creatinine  ...  L24:HDL Cholesterol  \
# 0     13.0     NaN            3.1  ...                  NaN
# 1     80.3     5.2            1.0  ...                  NaN
# 2     44.7    22.6            1.3  ...                  NaN
# 3     33.5    28.9            1.5  ...                 30.0
# 4    114.2     NaN            0.7  ...                  NaN
#
#    L25:Parathyroid hormone  L26:Vitamin D  L27:UrineAlbumin/Cr ratio  \
# 0                      NaN            NaN                        NaN
# 1                      NaN            NaN                        NaN
# 2                      NaN            NaN                        NaN
# 3                      NaN            NaN                        NaN
# 4                      NaN            NaN                        NaN
#
#    L28:UrineProtein/Cr ratio  L29:UrineVolume (24hrs)  L30:UrineUrea (24hrs)  \
# 0                        NaN                      NaN                    NaN
# 1                        NaN                      NaN                    NaN
# 2                        NaN                      NaN                    NaN
# 3                        NaN                      NaN                    NaN
# 4                       17.0                      NaN                    NaN
#
#    L31:UrineSodium (24hrs)  L32:UrineProtein (24hrs)  slope_Category
# 0                      NaN                       NaN          better
# 1                      NaN                       NaN           worse
# 2                      NaN                       NaN          better
# 3                      NaN                       NaN          better
# 4                      NaN                       NaN           worse
#
# [5 rows x 40 columns]

# %%
#เรียงให้คอลัมน์  'PatientUID', 'Slopes', 'eGFR_Category' มาอยู่ด้านหน้า
column_order = ['PatientUID', 'Slopes', 'slope_Category','Recent_eGFR'] + [col for col in slope.columns if col not in ['PatientUID', 'Slopes', 'slope_Category','Recent_eGFR']]
slope = slope[column_order]
slope.head()
# Out:
#    PatientUID     Slopes slope_Category  Recent_eGFR    BMI   BSA  \
# 0      924852   2.754717         better         15.8    NaN   NaN
# 1      989278 -46.720000          worse         32.3  18.71  1.70
# 2     2103792  11.018868         better         55.9  23.56  1.47
# 3      953611  17.222520         better         51.1  27.50  1.41
# 4      488150 -79.002653          worse         32.6    NaN   NaN
#
#    Diastolic BP  Systolic BP  L1:eGFR  L2:BUN  ...  L23:LDL Cholesterol  \
# 0          53.0        131.0     13.0     NaN  ...                  NaN
# 1          71.0        121.0     80.3     5.2  ...                  NaN
# 2          93.0        143.0     44.7    22.6  ...                  NaN
# 3          60.0        120.0     33.5    28.9  ...                147.0
# 4           NaN          NaN    114.2     NaN  ...                  NaN
#
#    L24:HDL Cholesterol  L25:Parathyroid hormone  L26:Vitamin D  \
# 0                  NaN                      NaN            NaN
# 1                  NaN                      NaN            NaN
# 2                  NaN                      NaN            NaN
# 3                 30.0                      NaN            NaN
# 4                  NaN                      NaN            NaN
#
#    L27:UrineAlbumin/Cr ratio  L28:UrineProtein/Cr ratio  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                       17.0
#
#    L29:UrineVolume (24hrs)  L30:UrineUrea (24hrs)  L31:UrineSodium (24hrs)  \
# 0                      NaN                    NaN                      NaN
# 1                      NaN                    NaN                      NaN
# 2                      NaN                    NaN                      NaN
# 3                      NaN                    NaN                      NaN
# 4                      NaN                    NaN                      NaN
#
#    L32:UrineProtein (24hrs)
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 40 columns]

# %%
# คำนวณเปอร์เซ็นต์ของค่าว่างทั้งหมดแยกตาม 'eGFR_Category'
missing_by_category = slope.groupby('slope_Category').apply(lambda x: round(x.isnull().mean().mean() * 100, 2))
missing_by_category
# Out:
# slope_Category
# better    51.93
# worse     51.92
# dtype: float64

# %%
slope_sort = slope.sort_values(by='Slopes', ascending=True)

# ใช้ตัวกรองเพื่อเลือกข้อมูลที่มี 'slope_Category' เป็น 'better'
better = slope_sort[slope_sort['slope_Category'] == 'better']

# คำนวณจำนวนค่าที่ขาดหายไปในแต่ละคอลัมน์
better_missing = better.isnull().sum()

# คำนวณเปอร์เซ็นต์ของค่าที่ขาดหายไปในแต่ละคอลัมน์
missing_percent = 100 * better_missing / len(better)

# สร้าง DataFrame ที่ประกอบด้วยจำนวนค่าที่ขาดหายไปและเปอร์เซ็นต์ของค่าที่ขาดหายไป
missing_1 = pd.DataFrame({
    'better_Missing Values': better_missing,
    'better_Missing Values (%)': missing_percent.round(2)
})
# สร้างตัวแปรเพื่อเก็บเฉพาะค่าว่าง
better_missing_values_only = missing_1[missing_1['better_Missing Values'] > 0]

# %%
worse = slope_sort[slope_sort['slope_Category'] == 'worse']
worse_missing = worse.isnull().sum()
missing_percent = 100 * worse_missing / len(worse)
missing_2 = pd.DataFrame({
    'worse_Missing Values': worse_missing,
    'worse_Missing Values (%)': missing_percent.round(2)
})
# สร้างตัวแปรเพื่อเก็บเฉพาะค่าว่าง
worse_missing_values_only = missing_2[missing_2['worse_Missing Values'] > 0]

# %%
# สร้างตารางที่รวมกันแนวคอลัมน์
combined_missing_values_slope = pd.concat([
    better_missing_values_only,
    worse_missing_values_only
], axis=1)

# แสดงผลลัพธ์ของตารางที่รวมกัน
combined_missing_values_slope
# Out:
#                            better_Missing Values  better_Missing Values (%)  \
# BMI                                         6542                      29.41
# BSA                                         6545                      29.42
# Diastolic BP                                3001                      13.49
# Systolic BP                                 2980                      13.40
# L1:eGFR                                        1                       0.00
# L2:BUN                                      5361                      24.10
# L3:Creatinine                                  1                       0.00
# L4:Sodium                                   8893                      39.97
# L5:Potassium                                7982                      35.88
# L6:Chloride                                 8928                      40.13
# L7:Bicarbonate                              8849                      39.78
# L8:Uric                                    16360                      73.54
# L9:Calcium                                 16968                      76.27
# L10:Phosphorus                             17125                      76.98
# L11:Albumin                                12511                      56.24
# L12:Hemoglobin                             10135                      45.56
# L13:Hematocrit                              9523                      42.81
# L14:WBC                                     9524                      42.81
# L15:Platelet                                9524                      42.81
# L16:TIBC                                   21846                      98.20
# L17:Tranferin SAT                          21893                      98.41
# L18:Ferritin                               21838                      98.16
# L19:Blood sugar                            10022                      45.05
# L20:HbA1c                                  12057                      54.20
# L21:Cholesterol                             7971                      35.83
# L22:Triglyceride                           11095                      49.87
# L23:LDL Cholesterol                         9895                      44.48
# L24:HDL Cholesterol                        11244                      50.54
# L25:Parathyroid hormone                    21855                      98.24
# L26:Vitamin D                              21676                      97.43
# L27:UrineAlbumin/Cr ratio                  21695                      97.52
# L28:UrineProtein/Cr ratio                  19938                      89.62
# L29:UrineVolume (24hrs)                    22092                      99.30
# L30:UrineUrea (24hrs)                      22086                      99.28
# L31:UrineSodium (24hrs)                    22138                      99.51
# L32:UrineProtein (24hrs)                   22003                      98.90
#
#                            worse_Missing Values  worse_Missing Values (%)
# BMI                                      8797.0                     28.96
# BSA                                      8804.0                     28.99
# Diastolic BP                             3841.0                     12.65
# Systolic BP                              3821.0                     12.58
# L1:eGFR                                     NaN                       NaN
# L2:BUN                                   7479.0                     24.62
# L3:Creatinine                               NaN                       NaN
# L4:Sodium                               12390.0                     40.79
# L5:Potassium                            11037.0                     36.34
# L6:Chloride                             12436.0                     40.94
# L7:Bicarbonate                          12355.0                     40.68
# L8:Uric                                 22538.0                     74.20
# L9:Calcium                              23476.0                     77.29
# L10:Phosphorus                          23654.0                     77.88
# L11:Albumin                             17399.0                     57.28
# L12:Hemoglobin                          13477.0                     44.37
# L13:Hematocrit                          12787.0                     42.10
# L14:WBC                                 12790.0                     42.11
# L15:Platelet                            12790.0                     42.11
# L16:TIBC                                29890.0                     98.41
# L17:Tranferin SAT                       29958.0                     98.63
# L18:Ferritin                            29887.0                     98.40
# L19:Blood sugar                         13281.0                     43.73
# L20:HbA1c                               15928.0                     52.44
# L21:Cholesterol                         11003.0                     36.23
# L22:Triglyceride                        15125.0                     49.80
# L23:LDL Cholesterol                     13500.0                     44.45
# L24:HDL Cholesterol                     15382.0                     50.64
# L25:Parathyroid hormone                 29882.0                     98.38
# L26:Vitamin D                           29674.0                     97.70
# L27:UrineAlbumin/Cr ratio               29621.0                     97.52
# L28:UrineProtein/Cr ratio               27214.0                     89.60
# L29:UrineVolume (24hrs)                 30188.0                     99.39
# L30:UrineUrea (24hrs)                   30138.0                     99.23
# L31:UrineSodium (24hrs)                 30198.0                     99.42
# L32:UrineProtein (24hrs)                30106.0                     99.12

# %% [markdown]
# #ทำ Visualization ด้วย Heatmap ตามค่า slope

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Count missing and non-missing values for each column by 'eGFR_Category'
missing_non_missing_count = slope_sort.groupby('slope_Category').apply(lambda x: x.isnull().mean() * 100)

# Transpose the DataFrame for better visualization
missing_non_missing_count = missing_non_missing_count.T

# Plotting the missing and non-missing counts as percentages
plt.figure(figsize=(12, 8))
sns.heatmap(missing_non_missing_count, cmap='viridis', annot=True, fmt='.2f', cbar_kws={'label': 'Percentage of Missing Values'})

plt.title('Percentage of Missing Values by slope_Category for Each Variable')
plt.xlabel('slope_Category')
plt.ylabel('Variables')
plt.show()
