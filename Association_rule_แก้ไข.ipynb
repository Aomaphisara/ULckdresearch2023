# %% [markdown]
# <a href="https://colab.research.google.com/github/Aomaphisara/ULckdresearch2023/blob/main/Association_rule_%E0%B9%81%E0%B8%81%E0%B9%89%E0%B9%84%E0%B8%82.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##  Apriori algorithm

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# Display options
pd.set_option('display.max_columns', None)  #ไม่กำหนดคอลัมน์สูงสุดที่แสดง
pd.set_option('display.max_rows', None) #ไม่กำหนดแถวสูงสุดที่แสดง
pd.set_option('display.max_colwidth', 999) #กำหนดความยาวสูงสุดของข้อมูลในแต่ละคอลัมน์ให้เท่ากับ 999
pd.options.display.float_format = "{:.3f}".format  # แสดงเป็นทศนิยม 3 ตำแหน่ง

# Apriori min support
min_support = 0.3 # stage 2,3 = 0.2

# Max length of apriori n-grams
max_len = 10

#frequent_items = apriori(df, use_colnames=True, min_support=min_support, max_len=max_len + 1)
#rules = association_rules(frequent_items, metric='lift', min_threshold=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## Load data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Mounted at /content/drive

# %% [markdown]
# ## Stage

# %% [markdown]
# #### stage 1

# %%
import pandas as pd
rules_eGFR_stage1 = pd.read_csv('/content/drive/MyDrive/ckdresearch2023/Assign/Association rule/stage_new/Ros_rule_stage1.csv', index_col=0)
rules_eGFR_stage1.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py:522: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   common = np.find_common_type([values.dtype, comps_array.dtype], [])
#                          antecedents                  consequents  \
# 97        frozenset({'NATNL_Asian'})  frozenset({'eGFR_stage_1'})
# 329  frozenset({'Potassium_Normal'})  frozenset({'eGFR_stage_1'})
# ...

# %%
rules_eGFR_stage1.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (248, 10)

# %%
# ใช้ query เพื่อเลือกรายการที่มี support ที่เริ่มต้นที่ 0.5 แต่น้อยกว่า 0.6
stage1 = rules_eGFR_stage1.query('support >= 0.3 and support < 0.4  and confidence >= 0.5').sort_values(by='confidence', ascending=False)

# แสดงผลลัพธ์
stage1.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (235, 10)

# %%
# ใช้ query เพื่อเลือกรายการที่มี support ที่เริ่มต้นที่ 0.5 แต่น้อยกว่า 0.6
stage1_1 = rules_eGFR_stage1.query('support >= 0.4 and support < 0.5  and confidence >= 0.5').sort_values(by='confidence', ascending=False)

# แสดงผลลัพธ์
stage1_1.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (13, 10)

# %%
stage1_1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                                                antecedents  \
# 36086        frozenset({'Potassium_Normal', 'Uric_Normal', 'NATNL_Asian'})
# 7678                        frozenset({'Potassium_Normal', 'Uric_Normal'})
# 2814                             frozenset({'Uric_Normal', 'NATNL_Asian'})
# 409                                             frozenset({'Uric_Normal'})
# 36920        frozenset({'UPCR_Normal', 'Potassium_Normal', 'NATNL_Asian'})
# 8021                        frozenset({'UPCR_Normal', 'Potassium_Normal'})
# 3201                             frozenset({'UPCR_Normal', 'NATNL_Asian'})
# ...

# %% [markdown]
# #### stage 2

# %%
import pandas as pd
rules_eGFR_stage2 = pd.read_csv('/content/drive/MyDrive/ckdresearch2023/Assign/Association rule/stage_new/True_stage2_rule.csv', index_col=0)
rules_eGFR_stage2.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py:522: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   common = np.find_common_type([values.dtype, comps_array.dtype], [])
#                          antecedents                  consequents  \
# 112       frozenset({'NATNL_Asian'})  frozenset({'eGFR_stage 2'})
# 366        frozenset({'BUN_Normal'})  frozenset({'eGFR_stage 2'})
# ...

# %%
rules_eGFR_stage2.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (15412, 10)

# %%
# ใช้ query เพื่อเลือกรายการที่มี support ที่เริ่มต้นที่ 0.2 แต่น้อยกว่า 0.3
stage2 = rules_eGFR_stage2.query('support >= 0.2 and support < 0.3').sort_values(by='confidence', ascending=False)

# แสดงผลลัพธ์
stage2.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (15078, 10)

# %%
# ใช้ query เพื่อเลือกรายการที่มี support ที่เริ่มต้นที่ 0.2 แต่น้อยกว่า 0.3
stage2 = rules_eGFR_stage2.query('support >= 0.2 and support < 0.3 and confidence >= 0.5').sort_values(by='confidence', ascending=False)

# แสดงผลลัพธ์
stage2.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (13, 10)

# %%
stage2
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                                                                                                    antecedents  \
# 85596                                                           frozenset({'Uric_Normal', 'NATNL_Asian', 'Hematocrit_Normal'})
# 12983                                                                          frozenset({'Uric_Normal', 'Hematocrit_Normal'})
# 1427678                                   frozenset({'Potassium_Normal', 'BUN_Normal', 'Calcium_Normal', 'Hematocrit_Normal'})
# ...

# %%
# ใช้ query เพื่อเลือกรายการที่มี support ที่เริ่มต้นที่ 0.3 แต่น้อยกว่า 0.4
stage2_1 = rules_eGFR_stage2.query('support >= 0.3 and support < 0.4').sort_values(by='confidence', ascending=False)

# แสดงผลลัพธ์
stage2_1.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (334, 10)

# %%
#stage2_1.to_excel('/content/drive/MyDrive/ckdresearch2023/Assign/Association rule/stage_new/stage2_1.xlsx')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# ใช้ query เพื่อเลือกรายการที่มี support ที่เริ่มต้นที่ 0.3 แต่น้อยกว่า 0.4
stage2_1 = rules_eGFR_stage2.query('support >= 0.3 and support < 0.4 and confidence >= 0.5').sort_values(by='confidence', ascending=False)

# แสดงผลลัพธ์
stage2_1.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (0, 10)

# %%
stage2_1.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                                         antecedents  \
# 12648                 frozenset({'Potassium_Normal', 'BUN_Normal'})
# 84798  frozenset({'Potassium_Normal', 'BUN_Normal', 'NATNL_Asian'})
# 84812   frozenset({'Chloride_Normal', 'BUN_Normal', 'NATNL_Asian'})
# 12654                  frozenset({'Chloride_Normal', 'BUN_Normal'})
# 84784     frozenset({'NATNL_Asian', 'BUN_Normal', 'Sodium_Normal'})
#
#                        consequents  antecedent support  consequent support  \
# 12648  frozenset({'eGFR_stage 2'})               0.662               0.380
# ...

# %%
# ใช้ query เพื่อเลือกรายการที่มี support ที่เริ่มต้นที่ 0.4 แต่น้อยกว่า 0.5
stage2_2 = rules_eGFR_stage2.query('support >= 0.4 and support < 0.5').sort_values(by='confidence', ascending=False)

# แสดงผลลัพธ์
stage2_2.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (0, 10)

# %% [markdown]
# #### stage 3

# %%
import pandas as pd
rules_eGFR_stage3 = pd.read_csv('/content/drive/MyDrive/ckdresearch2023/Assign/Association rule/stage_new/True_stage3_rul.csv', index_col=0)
rules_eGFR_stage3.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py:522: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   common = np.find_common_type([values.dtype, comps_array.dtype], [])
#                     antecedents                  consequents  \
# 14    frozenset({'OutPatient'})  frozenset({'eGFR_stage 3'})
# 56   frozenset({'G3M1-Statin'})  frozenset({'eGFR_stage 3'})
# 178     frozenset({'Sex_Male'})  frozenset({'eGFR_stage 3'})
# ...

# %%
rules_eGFR_stage3.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (39107, 10)

# %%
# ใช้ query เพื่อเลือกรายการที่มี support ที่เริ่มต้นที่ 0.2 แต่น้อยกว่า 0.3
stage3 = rules_eGFR_stage3.query('support >= 0.2 and support < 0.3 and confidence >= 0.5').sort_values(by='confidence', ascending=False)

# แสดงผลลัพธ์
stage3.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (34210, 10)

# %%
# ใช้ query เพื่อเลือกรายการที่มี support ที่เริ่มต้นที่ 0.3 แต่น้อยกว่า 0.4
stage3_1 = rules_eGFR_stage3.query('support >= 0.3 and support < 0.4 and confidence >= 0.5').sort_values(by='confidence', ascending=False)

# แสดงผลลัพธ์
stage3_1.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (4484, 10)

# %%
# ใช้ query เพื่อเลือกรายการที่มี support ที่เริ่มต้นที่ 0.4 แต่น้อยกว่า 0.5
stage3_1 = rules_eGFR_stage3.query('support >= 0.4 and support < 0.5 and confidence >= 0.5').sort_values(by='confidence', ascending=False)

# แสดงผลลัพธ์
stage3_1.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (411, 10)

# %%
#stage3_1.to_excel('/content/drive/MyDrive/ckdresearch2023/Assign/Association rule/stage_new/stage3_1.xlsx')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# ใช้ query เพื่อเลือกรายการที่มี support ที่เริ่มต้นที่ 0.5 แต่น้อยกว่า 0.6
stage3_2 = rules_eGFR_stage3.query('support >= 0.5 and support < 0.6 and confidence >= 0.5').sort_values(by='confidence', ascending=False)

# แสดงผลลัพธ์
stage3_2.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (2, 10)

# %%
stage3_2
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                        antecedents  \
# 403                  frozenset({'Albumin_Normal'})
# 4963  frozenset({'NATNL_Asian', 'Albumin_Normal'})
#
#                       consequents  antecedent support  consequent support  \
# 403   frozenset({'eGFR_stage 3'})               0.957               0.520
# 4963  frozenset({'eGFR_stage 3'})               0.952               0.520
#
#       support  confidence  lift  leverage  conviction  zhangs_metric
# 403     0.505       0.528 1.014     0.007       1.016          0.320
# 4963    0.502       0.527 1.014     0.007       1.015          0.279

# %% [markdown]
# #### stage 4

# %%
import pandas as pd
rule_egfr_4_ROS = pd.read_csv('/content/drive/MyDrive/ckdresearch2023/Assign/Association rule/stage_new/Ros_rule_stage4.csv', index_col=0)
rule_egfr_4_ROS.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py:522: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   common = np.find_common_type([values.dtype, comps_array.dtype], [])
#                           antecedents                  consequents  \
# 174            frozenset({'BSA_Low'})  frozenset({'eGFR_stage_4'})
# 209         frozenset({'DBP_Normal'})  frozenset({'eGFR_stage_4'})
# ...

# %%
rule_egfr_4_ROS.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (2551, 10)

# %%
# ใช้ query เพื่อเลือกรายการที่มี support ที่เริ่มต้นที่ 0.3 แต่น้อยกว่า 0.4
stage4 = rule_egfr_4_ROS.query('support >= 0.3 and support < 0.4 and confidence >= 0.5').sort_values(by='confidence', ascending=False)

# แสดงผลลัพธ์
stage4.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (2509, 10)

# %%
#stage4.to_excel('/content/drive/MyDrive/ckdresearch2023/Assign/Association rule/stage_new/stage4.xlsx')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# ใช้ query เพื่อเลือกรายการที่มี support ที่เริ่มต้นที่ 0.4 แต่น้อยกว่า 0.5
stage4_1 = rule_egfr_4_ROS.query('support >= 0.4 and support < 0.5 and confidence >= 0.5').sort_values(by='confidence', ascending=False)

# แสดงผลลัพธ์
stage4_1.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (42, 10)

# %%
#stage4_1.to_excel('/content/drive/MyDrive/ckdresearch2023/Assign/Association rule/stage_new/stage4_1.xlsx')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# ใช้ query เพื่อเลือกรายการที่มี support ที่เริ่มต้นที่ 0.5 แต่น้อยกว่า 0.6
stage4_2 = rule_egfr_4_ROS.query('support >= 0.5 and support < 0.6').sort_values(by='confidence', ascending=False)

# แสดงผลลัพธ์
stage4_2.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (0, 10)

# %% [markdown]
# ### stage 5

# %%
import pandas as pd
rule_egfr_5_ROS = pd.read_csv('/content/drive/MyDrive/ckdresearch2023/Assign/Association rule/stage_new/Ros_rule_stage5.csv', index_col=0)
rule_egfr_5_ROS.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py:522: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   common = np.find_common_type([values.dtype, comps_array.dtype], [])
#                            antecedents                  consequents  \
# 84          frozenset({'NATNL_Asian'})  frozenset({'eGFR_stage_5'})
# 146  frozenset({'BMI_Healthy weight'})  frozenset({'eGFR_stage_5'})
# ...

# %%
rule_egfr_5_ROS.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (889, 10)

# %%
# ใช้ query เพื่อเลือกรายการที่มี support ที่เริ่มต้นที่ 0.3 แต่น้อยกว่า 0.4
stage5 = rule_egfr_5_ROS.query('support >= 0.3 and support < 0.4 and confidence >= 0.5').sort_values(by='confidence', ascending=False)

# แสดงผลลัพธ์
stage5.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (832, 10)

# %%
#stage5.to_excel('/content/drive/MyDrive/ckdresearch2023/Assign/Association rule/stage_new/stage5.xlsx')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# ใช้ query เพื่อเลือกรายการที่มี support ที่เริ่มต้นที่ 0.4 แต่น้อยกว่า 0.5
stage5_1 = rule_egfr_5_ROS.query('support >= 0.4 and support < 0.5 and confidence >= 0.5').sort_values(by='confidence', ascending=False)

# แสดงผลลัพธ์
stage5_1.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (57, 10)

# %%
#stage5_1.to_excel('/content/drive/MyDrive/ckdresearch2023/Assign/Association rule/stage_new/stage5_1.xlsx')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# ใช้ query เพื่อเลือกรายการที่มี support ที่เริ่มต้นที่ 0.5 แต่น้อยกว่า 0.6
stage5_2 = rule_egfr_5_ROS.query('support >= 0.5 and support < 0.6').sort_values(by='confidence', ascending=False)

# แสดงผลลัพธ์
stage5_2.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (0, 10)
