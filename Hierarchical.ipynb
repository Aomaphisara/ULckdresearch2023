# %% [markdown]
# <a href="https://colab.research.google.com/github/Aomaphisara/ULckdresearch2023/blob/main/Hierarchical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/ckd/data.csv")

# %%
data = ['Slopes', 'eGFR_t1','TimeDiff',
   'Age', 'BMI', 'BSA', 'Diastolic-BP', 'Systolic-BP',
   'G1M2-ARB', 'G3M1-Statin',
       'G5M2-NSAIDs', 'G1M5-Diuretic', 'G1M7-Beta-blocker',
       'G1M3-Dihydropyridine-CCB', 'G1M6-MRA', 'G1M1-ACEI', 'G2M2-Metformin',
       'G2M3-DPP4-inhibitor', 'G2M1-SU', 'G3M3-Fibrate', 'G2M5-SGLT2i',
       'G4M1-Allopurinol', 'G1M9-Vasodilator', 'G1M8-Alpha-blocker',
       'G2M6-Insulin', 'G2M4-TZD', 'G4M2-Febuxostat', 'G3M2-Ezetimibe',
       'G1M4-Non-dihydropyridine-CCB', 'G5M1-Ketoanalog-amino-acid',
       'G2M7-GLP1-RA', 'G4M3-Uricosuric-agent',
   'D1-Hypertension',
       'D2-Diabetes-mellitus', 'D3-Dyslipidemia', 'D4-SLE',
       'D5-Systemic-sclerosis', 'D6-Rheumatoid-arthritis', 'D7-HIV-infection',
       'D8-HBV-infection', 'D9-HCV-infection', 'D10-Ischemic-heart-disease',
       'D11-Heart-failure', 'D12-Thalassemia', 'D13-Kidney-stone',
       'D14-Valvular-heart-disease', 'D15-Solid-malignancy',
       'D16-Hematologic-malignancy',
   'L1-eGFR', 'L2-BUN', 'L3-Creatinine',
       'L4-Sodium', 'L5-Potassium', 'L6-Chloride', 'L7-Bicarbonate', 'L8-Uric',
       'L9-Calcium', 'L10-Phosphorus', 'L11-Albumin', 'L12-Hemoglobin',
       'L13-Hematocrit', 'L14-WBC', 'L15-Platelet', 'L19-Blood-sugar',
       'L20-HbA1c', 'L21-Cholesterol', 'L22-Triglyceride',
       'L23-LDL-Cholesterol', 'L24-HDL-Cholesterol',
       'L28-UrineProtein-Cr-ratio']
data = df[data]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)
data = pd.DataFrame(scaled_data, columns=data.columns)

# %% [markdown]
# stage

# %%
stage = ['Slopes','TimeDiff',
   'Age', 'BMI', 'BSA', 'Diastolic-BP', 'Systolic-BP',
   'G1M2-ARB', 'G3M1-Statin',
       'G5M2-NSAIDs', 'G1M5-Diuretic', 'G1M7-Beta-blocker',
       'G1M3-Dihydropyridine-CCB', 'G1M6-MRA', 'G1M1-ACEI', 'G2M2-Metformin',
       'G2M3-DPP4-inhibitor', 'G2M1-SU', 'G3M3-Fibrate', 'G2M5-SGLT2i',
       'G4M1-Allopurinol', 'G1M9-Vasodilator', 'G1M8-Alpha-blocker',
       'G2M6-Insulin', 'G2M4-TZD', 'G4M2-Febuxostat', 'G3M2-Ezetimibe',
       'G1M4-Non-dihydropyridine-CCB', 'G5M1-Ketoanalog-amino-acid',
       'G2M7-GLP1-RA', 'G4M3-Uricosuric-agent',
   'D1-Hypertension',
       'D2-Diabetes-mellitus', 'D3-Dyslipidemia', 'D4-SLE',
       'D5-Systemic-sclerosis', 'D6-Rheumatoid-arthritis', 'D7-HIV-infection',
       'D8-HBV-infection', 'D9-HCV-infection', 'D10-Ischemic-heart-disease',
       'D11-Heart-failure', 'D12-Thalassemia', 'D13-Kidney-stone',
       'D14-Valvular-heart-disease', 'D15-Solid-malignancy',
       'D16-Hematologic-malignancy',
  'L2-BUN', 'L3-Creatinine',
       'L4-Sodium', 'L5-Potassium', 'L6-Chloride', 'L7-Bicarbonate', 'L8-Uric',
       'L9-Calcium', 'L10-Phosphorus', 'L11-Albumin', 'L12-Hemoglobin',
       'L13-Hematocrit', 'L14-WBC', 'L15-Platelet', 'L19-Blood-sugar',
       'L20-HbA1c', 'L21-Cholesterol', 'L22-Triglyceride',
       'L23-LDL-Cholesterol', 'L24-HDL-Cholesterol',
       'L28-UrineProtein-Cr-ratio']
stage = data[stage]

# %%
selected_data = stage.head(500)
selected_data.shape
# Out:
# (500, 68)

# %%
selected_data.head()
# Out:
#      Slopes  TimeDiff       Age       BMI    BSA Diastolic-BP Systolic-BP  \
# 0  0.386475  0.000000  0.654762  0.252676  0.195     0.587156    0.478571
# 1  0.454843  0.204051  0.666667  0.238841  0.190     0.486239    0.321429
# 2  0.392365  0.214921  0.678571  0.250587  0.190     0.596330    0.557143
# 3  0.356062  0.183300  0.690476  0.238841  0.180     0.504587    0.528571
# 4  0.577153  0.217885  0.714286  0.206996  0.165     0.422018    0.307143
#
#    G1M2-ARB G3M1-Statin G5M2-NSAIDs  ... L13-Hematocrit   L14-WBC  \
# 0  0.246575       0.000       0.000  ...       0.587567  0.128265
# 1  0.246575       0.225       0.000  ...       0.615970  0.136593
# 2  0.273973       0.250       0.170  ...       0.483582  0.284817
# 3  0.095890       0.000       0.005  ...       0.582881  0.108963
# 4  0.273973       0.000       0.075  ...       0.516418  0.145550
#
#   L15-Platelet L19-Blood-sugar L20-HbA1c L21-Cholesterol L22-Triglyceride  \
# 0     0.168811        0.053741  0.116727        0.222488         0.072967
# 1     0.227983        0.048472  0.159545        0.227273         0.052632
# 2     0.291624        0.063224  0.118182        0.196172         0.050239
# 3     0.179576        0.051633  0.142000        0.210526         0.058612
# 4     0.416753        0.050580  0.136364        0.202153         0.064593
#
#   L23-LDL-Cholesterol L24-HDL-Cholesterol L28-UrineProtein-Cr-ratio
# 0            0.389655            0.448864                  0.042122
# 1            0.468966            0.301136                  0.030457
# 2            0.410345            0.255682                  0.061882
# 3            0.444828            0.318182                  0.073980
# 4            0.410345            0.227273                  0.057483
#
# [5 rows x 68 columns]

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram
from sklearn.cluster import AgglomerativeClustering

def plot_dendrogram(model, **kwargs):
    # Create linkage matrix and then plot the dendrogram

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack(
        [model.children_, model.distances_, counts]
    ).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)

X = selected_data

# setting distance_threshold=0 ensures we compute the full tree.
model = AgglomerativeClustering(distance_threshold=0, n_clusters=None)

model = model.fit(X)
plt.title("Hierarchical Clustering Dendrogram")
# plot the top three levels of the dendrogram
plot_dendrogram(model, truncate_mode="level", p=3)
plt.xlabel("Number of points in node (or index of point if no parenthesis).")
plt.show()

# %% [markdown]
# #แบ่งตาม stage 5-6-7

# %%
from sklearn.cluster import AgglomerativeClustering
import numpy as np

stage_k5 = stage.copy()
clustering = AgglomerativeClustering(n_clusters = 5).fit(stage_k5)
stage_k5['5-Cluster'] = clustering.labels_
stage_k5.to_csv('stage_K5.csv', index=False)

stage_k6 = stage.copy()
clustering = AgglomerativeClustering(n_clusters = 6).fit(stage_k6)
stage_k6['6-Cluster'] = clustering.labels_
stage_k6.to_csv('stage_K6.csv', index=False)

stage_k7 = stage.copy()
clustering = AgglomerativeClustering(n_clusters = 7).fit(stage_k7)
stage_k7['7-Cluster'] = clustering.labels_
stage_k7.to_csv('stage_K7.csv', index=False)

# %% [markdown]
# ## Result Stage 5-6-7

# %%
import pandas as pd

# %%
stage_k5 = pd.read_csv('/content/drive/MyDrive/ckd/Agglomerative/stage_K5.csv')
stage_k5.head()
# Out:
#      Slopes  TimeDiff       Age       BMI       BSA  Diastolic-BP  \
# 0 -0.509876 -1.211010  0.531249 -1.055973 -1.625472      0.160130
# 1  0.788925  0.430160  0.617111 -1.201074 -1.686392     -0.793624
# 2 -0.397986  0.517584  0.702974 -1.077875 -1.686392      0.246834
# 3 -1.087639  0.263262  0.788837 -1.201074 -1.808232     -0.620214
# 4  3.112467  0.541426  0.960563 -1.535080 -1.990992     -1.400558
#
#    Systolic-BP  G1M2-ARB  G3M1-Statin  G5M2-NSAIDs  ...   L14-WBC  \
# 0    -0.525000  2.991739    -0.698699    -0.129510  ... -1.034716
# 1    -1.800103  2.991739     1.392719    -0.129510  ... -0.929884
# 2     0.112551  3.360578     1.625099     4.073425  ...  0.935901
# 3    -0.119286  0.963126    -0.698699    -0.005894  ... -1.277681
# 4    -1.916021  3.360578    -0.698699     1.724726  ... -0.817145
#
#    L15-Platelet  L19-Blood-sugar  L20-HbA1c  L21-Cholesterol  \
# 0     -0.702862        -0.599634  -0.882880         0.965478
# 1      0.060103        -0.701268  -0.546254         1.063652
# 2      0.880671        -0.416694  -0.871445         0.425522
# 3     -0.564056        -0.640287  -0.684192         0.720043
# 4      2.494071        -0.660614  -0.728504         0.548239
#
#    L22-Triglyceride  L23-LDL-Cholesterol  L24-HDL-Cholesterol  \
# 0         -0.803614             0.321723             3.686025
# 1         -1.038268             0.983545             1.640595
# 2         -1.065875             0.494372             1.011232
# 3         -0.969252             0.782121             1.876606
# 4         -0.900236             0.494372             0.617880
#
#    L28-UrineProtein-Cr-ratio  5-Cluster
# 0                  -1.158713          0
# 1                  -1.258996          0
# 2                  -0.988847          0
# 3                  -0.884842          0
# 4                  -1.026662          0
#
# [5 rows x 69 columns]

# %% [markdown]
# TSNE

# %%
stage_k6 = pd.read_csv('/content/drive/MyDrive/ckd/Agglomerative/stage_K6.csv')
stage_k6.head()
# Out:
#      Slopes  TimeDiff       Age       BMI       BSA  Diastolic-BP  \
# 0 -0.509876 -1.211010  0.531249 -1.055973 -1.625472      0.160130
# 1  0.788925  0.430160  0.617111 -1.201074 -1.686392     -0.793624
# 2 -0.397986  0.517584  0.702974 -1.077875 -1.686392      0.246834
# 3 -1.087639  0.263262  0.788837 -1.201074 -1.808232     -0.620214
# 4  3.112467  0.541426  0.960563 -1.535080 -1.990992     -1.400558
#
#    Systolic-BP  G1M2-ARB  G3M1-Statin  G5M2-NSAIDs  ...   L14-WBC  \
# 0    -0.525000  2.991739    -0.698699    -0.129510  ... -1.034716
# 1    -1.800103  2.991739     1.392719    -0.129510  ... -0.929884
# 2     0.112551  3.360578     1.625099     4.073425  ...  0.935901
# 3    -0.119286  0.963126    -0.698699    -0.005894  ... -1.277681
# 4    -1.916021  3.360578    -0.698699     1.724726  ... -0.817145
#
#    L15-Platelet  L19-Blood-sugar  L20-HbA1c  L21-Cholesterol  \
# 0     -0.702862        -0.599634  -0.882880         0.965478
# 1      0.060103        -0.701268  -0.546254         1.063652
# 2      0.880671        -0.416694  -0.871445         0.425522
# 3     -0.564056        -0.640287  -0.684192         0.720043
# 4      2.494071        -0.660614  -0.728504         0.548239
#
#    L22-Triglyceride  L23-LDL-Cholesterol  L24-HDL-Cholesterol  \
# 0         -0.803614             0.321723             3.686025
# 1         -1.038268             0.983545             1.640595
# 2         -1.065875             0.494372             1.011232
# 3         -0.969252             0.782121             1.876606
# 4         -0.900236             0.494372             0.617880
#
#    L28-UrineProtein-Cr-ratio  6-Cluster
# 0                  -1.158713          1
# 1                  -1.258996          1
# 2                  -0.988847          1
# 3                  -0.884842          1
# 4                  -1.026662          1
#
# [5 rows x 69 columns]

# %%
stage_k7 = pd.read_csv('/content/drive/MyDrive/ckd/Agglomerative/stage_K7.csv')
stage_k7.head()
# Out:
#      Slopes  TimeDiff       Age       BMI       BSA  Diastolic-BP  \
# 0 -0.509876 -1.211010  0.531249 -1.055973 -1.625472      0.160130
# 1  0.788925  0.430160  0.617111 -1.201074 -1.686392     -0.793624
# 2 -0.397986  0.517584  0.702974 -1.077875 -1.686392      0.246834
# 3 -1.087639  0.263262  0.788837 -1.201074 -1.808232     -0.620214
# 4  3.112467  0.541426  0.960563 -1.535080 -1.990992     -1.400558
#
#    Systolic-BP  G1M2-ARB  G3M1-Statin  G5M2-NSAIDs  ...   L14-WBC  \
# 0    -0.525000  2.991739    -0.698699    -0.129510  ... -1.034716
# 1    -1.800103  2.991739     1.392719    -0.129510  ... -0.929884
# 2     0.112551  3.360578     1.625099     4.073425  ...  0.935901
# 3    -0.119286  0.963126    -0.698699    -0.005894  ... -1.277681
# 4    -1.916021  3.360578    -0.698699     1.724726  ... -0.817145
#
#    L15-Platelet  L19-Blood-sugar  L20-HbA1c  L21-Cholesterol  \
# 0     -0.702862        -0.599634  -0.882880         0.965478
# 1      0.060103        -0.701268  -0.546254         1.063652
# 2      0.880671        -0.416694  -0.871445         0.425522
# 3     -0.564056        -0.640287  -0.684192         0.720043
# 4      2.494071        -0.660614  -0.728504         0.548239
#
#    L22-Triglyceride  L23-LDL-Cholesterol  L24-HDL-Cholesterol  \
# 0         -0.803614             0.321723             3.686025
# 1         -1.038268             0.983545             1.640595
# 2         -1.065875             0.494372             1.011232
# 3         -0.969252             0.782121             1.876606
# 4         -0.900236             0.494372             0.617880
#
#    L28-UrineProtein-Cr-ratio  7-Cluster
# 0                  -1.158713          1
# 1                  -1.258996          1
# 2                  -0.988847          1
# 3                  -0.884842          1
# 4                  -1.026662          1
#
# [5 rows x 69 columns]

# %%
import numpy as np
from sklearn.manifold import TSNE
import seaborn as sns
import pandas as pd

# Assuming stage_k5 is your DataFrame
y = stage_k5['5-Cluster']
X = stage_k5.drop(['5-Cluster'], axis=1)
tsne_k5 = TSNE(n_components=2, perplexity=40, random_state=42).fit_transform(X)

df = pd.DataFrame()
df["y"] = y
df["comp-1"] = tsne_k5[:, 0]
df["comp-2"] = tsne_k5[:, 1]

# Use Seaborn for scatter plot
sns.scatterplot(x="comp-1", y="comp-2", hue=df.y.tolist(),
                palette=sns.color_palette("bright", 5),
                data=df).set(title="5 Cluster by Stage T-SNE")
# Out:
# [Text(0.5, 1.0, '5 Cluster by Stage T-SNE')]

# %%
import numpy as np
from sklearn.manifold import TSNE
import seaborn as sns
import pandas as pd

y = stage_k6['6-Cluster']
X = stage_k6.drop(['6-Cluster'], axis=1)
tsne_k6 = TSNE(n_components=2, perplexity=40, random_state=42).fit_transform(X)

df = pd.DataFrame()
df["y"] = y
df["comp-1"] = tsne_k6[:, 0]
df["comp-2"] = tsne_k6[:, 1]

sns.scatterplot(x="comp-1", y="comp-2", hue=df.y.tolist(),
                palette=sns.color_palette("bright", 6),
                data=df).set(title="6 Cluster by Stage T-SNE")
# Out:
# [Text(0.5, 1.0, '6 Cluster by Stage T-SNE')]

# %%
import numpy as np
from sklearn.manifold import TSNE
import seaborn as sns
import pandas as pd

y = stage_k7['7-Cluster']
X = stage_k7.drop(['7-Cluster'], axis=1)
tsne_k7 = TSNE(n_components=2, perplexity=40, random_state=42).fit_transform(X)

df = pd.DataFrame()
df["y"] = y
df["comp-1"] = tsne_k7[:, 0]
df["comp-2"] = tsne_k7[:, 1]

sns.scatterplot(x="comp-1", y="comp-2", hue=df.y.tolist(),
                palette=sns.color_palette("bright", 7),
                data=df).set(title="7 Cluster by Stage T-SNE")
# Out:
# [Text(0.5, 1.0, '7 Cluster by Stage T-SNE')]

# %% [markdown]
# slope

# %% [markdown]
# #แบ่งตาม slope 2-3-4

# %%
slope = [ 'Age', 'BMI', 'BSA', 'Diastolic-BP', 'Systolic-BP',
   'G1M2-ARB', 'G3M1-Statin',
       'G5M2-NSAIDs', 'G1M5-Diuretic', 'G1M7-Beta-blocker',
       'G1M3-Dihydropyridine-CCB', 'G1M6-MRA', 'G1M1-ACEI', 'G2M2-Metformin',
       'G2M3-DPP4-inhibitor', 'G2M1-SU', 'G3M3-Fibrate', 'G2M5-SGLT2i',
       'G4M1-Allopurinol', 'G1M9-Vasodilator', 'G1M8-Alpha-blocker',
       'G2M6-Insulin', 'G2M4-TZD', 'G4M2-Febuxostat', 'G3M2-Ezetimibe',
       'G1M4-Non-dihydropyridine-CCB', 'G5M1-Ketoanalog-amino-acid',
       'G2M7-GLP1-RA', 'G4M3-Uricosuric-agent',
   'D1-Hypertension',
       'D2-Diabetes-mellitus', 'D3-Dyslipidemia', 'D4-SLE',
       'D5-Systemic-sclerosis', 'D6-Rheumatoid-arthritis', 'D7-HIV-infection',
       'D8-HBV-infection', 'D9-HCV-infection', 'D10-Ischemic-heart-disease',
       'D11-Heart-failure', 'D12-Thalassemia', 'D13-Kidney-stone',
       'D14-Valvular-heart-disease', 'D15-Solid-malignancy',
       'D16-Hematologic-malignancy',
  'L2-BUN', 'L3-Creatinine',
       'L4-Sodium', 'L5-Potassium', 'L6-Chloride', 'L7-Bicarbonate', 'L8-Uric',
       'L9-Calcium', 'L10-Phosphorus', 'L11-Albumin', 'L12-Hemoglobin',
       'L13-Hematocrit', 'L14-WBC', 'L15-Platelet', 'L19-Blood-sugar',
       'L20-HbA1c', 'L21-Cholesterol', 'L22-Triglyceride',
       'L23-LDL-Cholesterol', 'L24-HDL-Cholesterol',
       'L28-UrineProtein-Cr-ratio']
slope = data[slope]

# %%
from sklearn.cluster import AgglomerativeClustering
import numpy as np

slope_k2 = slope.copy()
clustering = AgglomerativeClustering(n_clusters = 2).fit(slope_k2)
slope_k2['2-Cluster'] = clustering.labels_
slope_k2.to_csv('slope_K2.csv', index=False)

slope_k3 = slope.copy()
clustering = AgglomerativeClustering(n_clusters = 3).fit(slope_k3)
slope_k3['3-Cluster'] = clustering.labels_
slope_k3.to_csv('slope_K3.csv', index=False)

slope_k4 = slope.copy()
clustering = AgglomerativeClustering(n_clusters = 4).fit(slope_k4)
slope_k4['4-Cluster'] = clustering.labels_
slope_k4.to_csv('slope_K4.csv', index=False)

# %% [markdown]
# ## Result Slope 3-4-5

# %%
slope_k2 = pd.read_csv('/content/drive/MyDrive/ckd/Agglomerative/slope_K2.csv')
slope_k2.head()
# Out:
#         Age       BMI       BSA  Diastolic-BP  Systolic-BP  G1M2-ARB  \
# 0  0.531249 -1.055973 -1.625472      0.160130    -0.525000  2.991739
# 1  0.617111 -1.201074 -1.686392     -0.793624    -1.800103  2.991739
# 2  0.702974 -1.077875 -1.686392      0.246834     0.112551  3.360578
# 3  0.788837 -1.201074 -1.808232     -0.620214    -0.119286  0.963126
# 4  0.960563 -1.535080 -1.990992     -1.400558    -1.916021  3.360578
#
#    G3M1-Statin  G5M2-NSAIDs  G1M5-Diuretic  G1M7-Beta-blocker  ...   L14-WBC  \
# 0    -0.698699    -0.129510      -0.176477          -0.333859  ... -1.034716
# 1     1.392719    -0.129510      -0.176477          -0.333859  ... -0.929884
# 2     1.625099     4.073425      -0.176477          -0.333859  ...  0.935901
# 3    -0.698699    -0.005894       2.205286          -0.333859  ... -1.277681
# 4    -0.698699     1.724726      -0.176477          -0.333859  ... -0.817145
#
#    L15-Platelet  L19-Blood-sugar  L20-HbA1c  L21-Cholesterol  \
# 0     -0.702862        -0.599634  -0.882880         0.965478
# 1      0.060103        -0.701268  -0.546254         1.063652
# 2      0.880671        -0.416694  -0.871445         0.425522
# 3     -0.564056        -0.640287  -0.684192         0.720043
# 4      2.494071        -0.660614  -0.728504         0.548239
#
#    L22-Triglyceride  L23-LDL-Cholesterol  L24-HDL-Cholesterol  \
# 0         -0.803614             0.321723             3.686025
# 1         -1.038268             0.983545             1.640595
# 2         -1.065875             0.494372             1.011232
# 3         -0.969252             0.782121             1.876606
# 4         -0.900236             0.494372             0.617880
#
#    L28-UrineProtein-Cr-ratio  2-Cluster
# 0                  -1.158713          1
# 1                  -1.258996          1
# 2                  -0.988847          1
# 3                  -0.884842          1
# 4                  -1.026662          1
#
# [5 rows x 67 columns]

# %%
slope_k3 = pd.read_csv('/content/drive/MyDrive/ckd/Agglomerative/slope_K3.csv')
slope_k3.head()
# Out:
#         Age       BMI       BSA  Diastolic-BP  Systolic-BP  G1M2-ARB  \
# 0  0.531249 -1.055973 -1.625472      0.160130    -0.525000  2.991739
# 1  0.617111 -1.201074 -1.686392     -0.793624    -1.800103  2.991739
# 2  0.702974 -1.077875 -1.686392      0.246834     0.112551  3.360578
# 3  0.788837 -1.201074 -1.808232     -0.620214    -0.119286  0.963126
# 4  0.960563 -1.535080 -1.990992     -1.400558    -1.916021  3.360578
#
#    G3M1-Statin  G5M2-NSAIDs  G1M5-Diuretic  G1M7-Beta-blocker  ...   L14-WBC  \
# 0    -0.698699    -0.129510      -0.176477          -0.333859  ... -1.034716
# 1     1.392719    -0.129510      -0.176477          -0.333859  ... -0.929884
# 2     1.625099     4.073425      -0.176477          -0.333859  ...  0.935901
# 3    -0.698699    -0.005894       2.205286          -0.333859  ... -1.277681
# 4    -0.698699     1.724726      -0.176477          -0.333859  ... -0.817145
#
#    L15-Platelet  L19-Blood-sugar  L20-HbA1c  L21-Cholesterol  \
# 0     -0.702862        -0.599634  -0.882880         0.965478
# 1      0.060103        -0.701268  -0.546254         1.063652
# 2      0.880671        -0.416694  -0.871445         0.425522
# 3     -0.564056        -0.640287  -0.684192         0.720043
# 4      2.494071        -0.660614  -0.728504         0.548239
#
#    L22-Triglyceride  L23-LDL-Cholesterol  L24-HDL-Cholesterol  \
# 0         -0.803614             0.321723             3.686025
# 1         -1.038268             0.983545             1.640595
# 2         -1.065875             0.494372             1.011232
# 3         -0.969252             0.782121             1.876606
# 4         -0.900236             0.494372             0.617880
#
#    L28-UrineProtein-Cr-ratio  3-Cluster
# 0                  -1.158713          0
# 1                  -1.258996          0
# 2                  -0.988847          0
# 3                  -0.884842          0
# 4                  -1.026662          0
#
# [5 rows x 67 columns]

# %%
slope_k4 = pd.read_csv('/content/drive/MyDrive/ckd/Agglomerative/slope_K4.csv')
slope_k4.head()
# Out:
#         Age       BMI       BSA  Diastolic-BP  Systolic-BP  G1M2-ARB  \
# 0  0.531249 -1.055973 -1.625472      0.160130    -0.525000  2.991739
# 1  0.617111 -1.201074 -1.686392     -0.793624    -1.800103  2.991739
# 2  0.702974 -1.077875 -1.686392      0.246834     0.112551  3.360578
# 3  0.788837 -1.201074 -1.808232     -0.620214    -0.119286  0.963126
# 4  0.960563 -1.535080 -1.990992     -1.400558    -1.916021  3.360578
#
#    G3M1-Statin  G5M2-NSAIDs  G1M5-Diuretic  G1M7-Beta-blocker  ...   L14-WBC  \
# 0    -0.698699    -0.129510      -0.176477          -0.333859  ... -1.034716
# 1     1.392719    -0.129510      -0.176477          -0.333859  ... -0.929884
# 2     1.625099     4.073425      -0.176477          -0.333859  ...  0.935901
# 3    -0.698699    -0.005894       2.205286          -0.333859  ... -1.277681
# 4    -0.698699     1.724726      -0.176477          -0.333859  ... -0.817145
#
#    L15-Platelet  L19-Blood-sugar  L20-HbA1c  L21-Cholesterol  \
# 0     -0.702862        -0.599634  -0.882880         0.965478
# 1      0.060103        -0.701268  -0.546254         1.063652
# 2      0.880671        -0.416694  -0.871445         0.425522
# 3     -0.564056        -0.640287  -0.684192         0.720043
# 4      2.494071        -0.660614  -0.728504         0.548239
#
#    L22-Triglyceride  L23-LDL-Cholesterol  L24-HDL-Cholesterol  \
# 0         -0.803614             0.321723             3.686025
# 1         -1.038268             0.983545             1.640595
# 2         -1.065875             0.494372             1.011232
# 3         -0.969252             0.782121             1.876606
# 4         -0.900236             0.494372             0.617880
#
#    L28-UrineProtein-Cr-ratio  4-Cluster
# 0                  -1.158713          0
# 1                  -1.258996          0
# 2                  -0.988847          0
# 3                  -0.884842          0
# 4                  -1.026662          0
#
# [5 rows x 67 columns]

# %%
import numpy as np
from sklearn.manifold import TSNE
import seaborn as sns
import pandas as pd

# Assuming stage_k5 is your DataFrame
y = slope_k2 ['2-Cluster']
X = slope_k2 .drop(['2-Cluster'], axis=1)
tsne_k2 = TSNE(n_components=2, perplexity=40, random_state=42).fit_transform(X)

df = pd.DataFrame()
df["y"] = y
df["comp-1"] = tsne_k2[:, 0]
df["comp-2"] = tsne_k2[:, 1]

# Use Seaborn for scatter plot
sns.scatterplot(x="comp-1", y="comp-2", hue=df.y.tolist(),
                palette=sns.color_palette("bright", 2),
                data=df).set(title="2 Cluster by Slope T-SNE")
# Out:
# [Text(0.5, 1.0, '2 Cluster by Slope T-SNE')]

# %%
import numpy as np
from sklearn.manifold import TSNE
import seaborn as sns
import pandas as pd

# Assuming stage_k5 is your DataFrame
y = slope_k3 ['3-Cluster']
X = slope_k3 .drop(['3-Cluster'], axis=1)
tsne_k3 = TSNE(n_components=2, perplexity=40, random_state=42).fit_transform(X)

df = pd.DataFrame()
df["y"] = y
df["comp-1"] = tsne_k3[:, 0]
df["comp-2"] = tsne_k3[:, 1]

# Use Seaborn for scatter plot
sns.scatterplot(x="comp-1", y="comp-2", hue=df.y.tolist(),
                palette=sns.color_palette("bright", 3),
                data=df).set(title="3 Cluster by Slope T-SNE")
# Out:
# [Text(0.5, 1.0, '3 Cluster by Slope T-SNE')]

# %%
import numpy as np
from sklearn.manifold import TSNE
import seaborn as sns
import pandas as pd

# Assuming stage_k5 is your DataFrame
y = slope_k4 ['4-Cluster']
X = slope_k4 .drop(['4-Cluster'], axis=1)
tsne_k4 = TSNE(n_components=2, perplexity=40, random_state=42).fit_transform(X)

df = pd.DataFrame()
df["y"] = y
df["comp-1"] = tsne_k4[:, 0]
df["comp-2"] = tsne_k4[:, 1]

# Use Seaborn for scatter plot
sns.scatterplot(x="comp-1", y="comp-2", hue=df.y.tolist(),
                palette=sns.color_palette("bright", 4),
                data=df).set(title="4 Cluster by Slope T-SNE")
# Out:
# [Text(0.5, 1.0, '4 Cluster by Slope T-SNE')]
